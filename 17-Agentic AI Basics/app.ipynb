# %%
def calculator_tool(a,b):
    return a*b

def weather_tool(city):
    return (
        {
            "city": city,
            "temperature": 30,
            "condition": "sunny"
        }
    )

def search_tool(query):
    return(f"Result of your query {query}")


tools = {
    "calculator": calculator_tool, 
    "weather": weather_tool,
    "search": search_tool
}

tool_name = "calculator"

result = tools[tool_name]

print(result)

# %%
from datetime import datetime
import re
current_date = datetime.date(datetime.now())
print(current_date)
# Out:
# 2026-05-17
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import requests
def api_call(ticker,url,params,field):
    
    if not ticker:
        raise Exception(f'Ticker missing for {field} fetch')

    api_url = url

    try:
        response = requests.get(api_url,params=params,headers=HEADERS).json()
        return(response)
    except Exception as ex1:
        print(f"api call failed exception: {ex1}")
        # emit_event({'type': 'error', 'text': f'Failed to fetch {field} for {ticker}'})
        response = 'none'
        return response

FALL_API_KEY = 'D5UBRFGP3EKH7ROG'

def fall_back_price(ticker,url):
    print(f"Falling back to secondary method for price for {ticker}")
    function = 'TIME_SERIES_DAILY'
    params = {
        'function': function,
        'symbol': ticker,
        'apikey': FALL_API_KEY
    }
    
    response = api_call(ticker,url,params=params,field='fallback_price')
    print(response)
    fallback_price = response
    if response.status_code == 200:
        try:
            data = response.json()
            time_series = data.get('Time Series (Daily)', {})
            if time_series:
                latest_date = sorted(time_series.keys())[-1]
                fallback_price = time_series[latest_date]['4. close']
                fallback_price = float(fallback_price)
            else:
                print(f"No time series data found for {ticker} in fallback API.")
        except Exception as e:
            print(f"Error parsing fallback API response for {ticker}: {e}")

    return fallback_price

fall_back_price('MSFT','https://www.alphavantage.co/query')
# Out:
# Falling back to secondary method for price for MSFT
# api call failed exception: name 'HEADERS' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10, in api_call(ticker, url, params, field)
#       9 try:
# ---> 10     response = requests.get(api_url,params=params,headers=HEADERS).json()
#      11     return(response)
#
# NameError: name 'HEADERS' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 47
#      43             print(f"Error parsing fallback API response for {ticker}: {e}")
#      45     return fallback_price
# ---> 47 fall_back_price('MSFT','https://www.alphavantage.co/query')
#
# Cell In[2], line 29, in fall_back_price(ticker, url)
#      22 function = 'TIME_SERIES_DAILY'
#      23 params = {
#      24     'function': function,
#      25     'symbol': ticker,
#      26     'apikey': FALL_API_KEY
#      27 }
# ---> 29 response = api_call(ticker,url,params=params,field='fallback_price')
#      30 print(response)
#      31 fallback_price = response
#
# Cell In[2], line 14, in api_call(ticker, url, params, field)
#      12 except Exception as ex1:
#      13     print(f"api call failed exception: {ex1}")
# ---> 14     emit_event({'type': 'error', 'text': f'Failed to fetch {field} for {ticker}'})
#      15     response = 'none'
#      16     return response
#
# NameError: name 'emit_event' is not defined

# %%
def agent_router(query):
    if "weather" in query.lower():
        return "weather"
    elif "calculate" in query.lower():
        return "calculate"
    elif "search" in query.lower():
        return "search"
    else:
        return "unknown"

# %%
import sys
user_query = input(f'Input your query? ')

def agent_router(query):
    if "weather" in query.lower():
        return "weather"
    elif "calculate" in query.lower():
        return "calculator"
    elif "search" in query.lower():
        return "search"
    else:
        return "unknown"

agent_tool = agent_router(user_query)

print(agent_tool)

def calculator_tool(a,b):
    return a*b

def weather_tool(city):
    return (
        {
            "city": city,
            "temperature": 30,
            "condition": "sunny"
        }
    )

def search_tool(query):
    return(f"Result of your query {query}")


tools = {
    "calculator": calculator_tool, 
    "weather": weather_tool,
    "search": search_tool
}


try:
    tool_to_call = tools[agent_tool]
except KeyError:
    print(f'alter the query as per the agent requirement')
    sys.exit()

if agent_tool == 'weather':
    print(tool_to_call('India'))
elif agent_tool == 'calculator':
    print(tool_to_call(5,6))
elif agent_tool == 'search':
    print(tool_to_call(user_query))
else:
    print('No tools in Toolbox. Try with different query')

# %%
# %pip install openai

# %%
from google import genai

user_query = input('Enter the query for your agent')  #Goal to solve

def llmcall(query): #Thinking layer
    prompt = f"""
You are an AI agent.

Available tools:
1. weather
2. calculator
3. search

User query:
{query}

Return the tool name and its parameters

Parameters as below:

weather: Keys for dictionary - Tool, City
Calcualtor : Tool, number1, number2, function (the value of function should be +,-,*,/)
search : Tool, Topic
.
""" 
    client = genai.Client(api_key='AIzaSyBVMa3VTdRzn4PyfowHXYUFGyAnVRarLPY')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )
    
    return response.text

def calculator_tool(a,b):
    return a*b

def weather_tool(city):
    return (
        {
            "city": city,
            "temperature": 30,
            "condition": "sunny"
        }
    )

def search_tool(query):
    return(f"Result of your query {query}")


#Tool set
tools = {
    "calculator": calculator_tool, 
    "weather": weather_tool,
    "search": search_tool
}

agent_tool = llmcall(user_query)  # Thinking


try:
    tool_to_call = tools[agent_tool] 
except KeyError:
    print(f'alter the query as per the agent requirement')
    sys.exit()

#Act 

if agent_tool == 'weather':
    print(tool_to_call('India'))
elif agent_tool == 'calculator':
    print(tool_to_call(5,6))
elif agent_tool == 'search':
    print(tool_to_call(user_query))
else:
    print('No tools in Toolbox. Try with different query')

# %%
print(llmcall(user_query))

def calculator_tool(fun,num1,num2):
    if fun == '+':
        return num1 + num2
    elif fun == '-':
        return num1 - num2
    elif fun == '*':
        return num1 * num2
    elif fun == '/':
        return num1/num2
    else:
        print('Simple Calculator can handle only +, - , *, /')

def weather_tool(city_name):
    return (
        {
            "city": city_name,
            "temperature": 30
        }
    )

def search_tool(topic_in_query):
    return (f"The result of query is {topic_in_query}")

tool_repository = {
    "calculator": calculator_tool,
    "weather": weather_tool,
    'search': search_tool
}

response_from_llm = llmcall(user_query)
agent_tool = response_from_llm['Tool']

if agent_tool == 'calculator':
    number_1,number_2,operation = response_from_llm['number1'], response_from_llm['number2'], response_from_llm['function']
    print(tool_repository[agent_tool](operation,number_1,number_2))
elif agent_tool == 'weather':
    city_response = response_from_llm['City']
    print(tool_repository[agent_tool](city_response))
elif agent_tool == 'search': 
    search_response = response_from_llm['Topic']
    print(tool_repository[agent_tool](search_response))
else:
    print(f'Incorrect response - {agent_tool}, {response_from_llm['Tool']}')

# %%
from google import genai
import json

user_query = input('Enter the query for your agent')  #Goal to solve

def llmcall(query): #Thinking layer
    prompt = f"""
You are an AI agent.

Available tools:
1. weather
2. calculator
3. search

User query:
{query}

Return ONLY the tool name and its parameters

Example for weather should return like
            "Tool": 'weather',
            "City": 'Chennai'

Parameters as below in python format and return only raw JSON 

Dont include:
markdowns
explanations
text

weather: Keys for dict - Tool, City
Calcualtor : Tool, number1, number2, function (the value of function should be +,-,*,/)
search : Tool, Topic

.
""" 
    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )
    
    return json.loads(response.text)

def calculator_tool(fun,num1,num2):
    if fun == '+':
        return num1 + num2
    elif fun == '-':
        return num1 - num2
    elif fun == '*':
        return num1 * num2
    elif fun == '/':
        return num1/num2
    else:
        print('Simple Calculator can handle only +, - , *, /')

def weather_tool(city_name):
    return (
        {
            "city": city_name,
            "temperature": 30
        }
    )

def search_tool(topic_in_query):
    return (f"The result of query is {topic_in_query}")

tool_repository = {
    "calculator": calculator_tool,
    "weather": weather_tool,
    'search': search_tool
}

response_from_llm = llmcall(user_query)
agent_tool = response_from_llm['Tool']

if agent_tool == 'calculator':
    number_1,number_2,operation = response_from_llm['number1'], response_from_llm['number2'], response_from_llm['function']
    print(tool_repository[agent_tool](operation,number_1,number_2))
elif agent_tool == 'weather':
    city_response = response_from_llm['City']
    print(tool_repository[agent_tool](city_response))
elif agent_tool == 'search': 
    search_response = response_from_llm['Topic']
    print(tool_repository[agent_tool](search_response))
else:
    print(f'Incorrect response - {agent_tool}, {response_from_llm['Tool']}')

# %%
from google import genai
import json
import re

user_query = input('Enter the query for your agent')  #Goal to solve

tools = {
    "weather": {
        "description": "Get weather of a city",
        "parameters": {
            "city": "string"
        }
    },
    "calculator": {
        "description": "perform math calculation",
        "parameters": {
            "expression": "string"
        }
    },
    "search": {
        "description": "search in internet",
        "parameters": {
            "expression": "string"
        }
    }
}

def llmcall(query): #Thinking layer
    prompt = f"""
You are an AI agent.

Available tools:

1. weather
   description: Get weather of a city
   parameters:
      city (string)

2. calculator
   description: Perform math calculations
   parameters:
      expression (string)
3. search
    description: search in internet
    parameters: 
        expression (string)

user query :
{query}

Return should be in JSON format

For Example: 


Dont include:
markdowns
explanations
text

.
""" 
    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )
    
    return (json.loads(response.text))


def calculator_tool(expression):

    # allow only numbers and operators
    if not re.match(r'^[0-9+\-*/(). ]+$', expression):
        return "Invalid expression"

    try:
        result = eval(expression, {"__builtins__": None}, {})
        return result
    except Exception:
        return "Calculation error"
    
def weather_tool(city_name):
    return (
        {
            "city": city_name,
            "Temperature": 23
        }
    )

def search_tool(to_find):
    return {
        "to_find": to_find
    }

tool_repository = {
    "calculator": calculator_tool,
    "weather": weather_tool,
    "search": search_tool
}

response_out = llmcall(user_query)
print(response_out)
tool_to_call = response_out['tool']

if tool_to_call == 'calculator':
    parameters = response_out['parameters']['expression']
    print(calculator_tool(parameters))
elif tool_to_call == 'weather':
    parameters = response_out['parameters']['city']
    print(weather_tool(parameters))
elif tool_to_call == 'search':
    parameters = response_out['parameters']['expression']
    print(search_tool(parameters))
else:
    print('unknown response from LLM')

# %%
from google import genai 
import json
import re

user_query = input('Give a complex query to answer')
results = []
memory = []

def task_list(query):
    prompt = f"""
You are an AI agent.

Your task is create task list from a given query

user query :
{query}

Return should be in List of Dictionary:

For Example: 

What is Tesla stock price and what would be the cost if i need to buy 100 shares. 

List of tasks 
task1 is search telsa stock price 
task2 is multiply telsa stock price by 100

Result should be like 'search telsa stock price', 'multiply telsa stock price by 100' 

Dont include:
markdowns
explanations
text
Square braces

Return output strictly in array format.

Example:
"search Tesla stock price","multiply Tesla stock price by 20"

""" 
    
    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )

    return ((response.text).split(','))

def llmcall(query): #Thinking layer
    print(query)
    print(memory)
    prompt_new = f"""
You are an AI agent.

Available tools:

1. weather
   description: Get weather of a city
   parameters:
      city (string)

2. calculator
   description: Perform math calculations
   parameters:
      expression (string)
3. search
    description: search in internet
    parameters: 
        expression (string)

user query :
{query}

If the current task depends on previous results,
use the values from previous_observation to complete the task.

Example:
Previous observation:
Tesla stock price = 240

Task:
calculate value of 20 shares

Output IN JSON format:
"tool":"calculator","expression":"240 * 20"

previous_observation:

{memory}

The user query here is a task - you need to create output in json format
Don't create List


for calculator - key should only be "tool" and "expression"
for weather - key should only be "tool" and "city" 
for search -  key should only be "tool" and "expression"

Use search tool for:
- company information
- people
- facts
- internet queries

Use calculator tool for:
- math expressions

Use weather tool for:
- weather questions

This should be in JSON format that a JSON decoder should understand 

Dont include:
markdowns
explanations
text
lists

.
""" 
    client_new = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    response_new = client_new.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents={"text": prompt_new}
    )
    
    print(f" after calling LLM: {response_new.text}")
    return (json.loads(response_new.text))

tool_repository = {
    "calculator": "calculator_tool",
    "weather": "weather_tool",
    "search": "search_tool"
}

def execution_layer(data):
    if data['tool'] not in tool_repository:
        return "we don't have a tool to work on this query"
    
    if data['tool'] == 'calculator':
        expression = data['expression']
        if not re.match(r'^[0-9+\-*/(). ]+$', expression):
            return "Invalid expression"

        try:
            result = eval(expression, {"__builtins__": None}, {})
            return result
        except Exception:
            return "Calculation error"

    elif data['tool'] == 'weather':
        city_name = data['city']
        return (f"temperature of {city_name}= 20")
    elif data['tool'] == 'search':
        query_val = data['expression']
        return (240)
    

tasks = task_list(user_query)

print(tasks)

for task in tasks:
    print(task)
    decision = llmcall(task)
    print(decision)
    result = execution_layer(decision)
    memory.append(
        {
            "task": task,
            "tool": decision["tool"],
            "result": result
        }
    )
    results.append(result)

print(results)

# %%
from google import genai
import re
import json
import requests

user_query = input()

def task_generator(query):
    prompt  = f""" 
    You are an AI Agent.

    Your job is to create a task list in JSON format 

    query: {query}
    
    From the given query you need to break the task in JSON format

    For each task provide:
    -id
    -task_description
    -depends_on (list of task ids)

    Rules:
    Tasks must be atomic 
    Dependencies must be logical 
    Avoid unneccessary dependecies 
    Allow parallel taks if possible

    Return only JSON

    Don't include:
    Markdowns
    text
    wildcards 
    explanations
    breaks

    """

    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )

    return (response.text)

def call_llm(prompt):
    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    res_llm = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )
    return (res_llm.text)   

memory = {}
result_memory={}
recent_news = []


tasks = json.loads(task_generator(user_query))

completed = set()

def execute(task):
    inputs = []
    task_words = task['task_description'].lower().split()
    if "ticker" in (task['task_description'].lower()).split() and "identify" in (task['task_description'].lower()).split():
        prompt = f"""
        Extract the company name from the text.

        Return only the company name without a '.' at end
        No explanation.

            Text: {task['task_description']}
        """
        company_name = (call_llm(prompt)).replace('.','')
        print(company_name)

        api_url = "https://finnhub.io/api/v1/search"

        params = { 
            "q": company_name,
            "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
        }

        resp = requests.get(api_url,params=params).json()
        result_memory["ticker"]=(resp)['result'][0]['displaySymbol']
        

    elif "price" in task_words and ("retrieve"  in task_words or "fetch" in task_words):
        api_url = "https://finnhub.io/api/v1/quote"

        params = { 
            "symbol": result_memory["ticker"],
            "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
        }

        resp_price = requests.get(api_url,params=params).json()
        if "closing" in task_words:
            result_memory["closing_price"]=(resp_price)['c']
        else:
            result_memory["change"]=(resp_price)['d']
            result_memory["percentage_change"]=(resp_price)['dp']
            result_memory["high_price"]=(resp_price)['h']
            result_memory["low_price"]=(resp_price)['l']
            result_memory["Open_price"]=(resp_price)['o']
            result_memory["prev_close"]=(resp_price)['pc']
            

    elif "news" in task_words and ("gather" in task_words or "retrieve" in task_words or "get" in task_words):
        url = "https://newsapi.org/v2/everything"
        params = {
            "q":result_memory["ticker"],
            "searchIn": "title",
            "apiKey": "7edafe2e5d804d59b16f305502fc5c54"
        }

        res = requests.get(url, params=params).json()
        i=0
        while i < 6:
            news = (res['articles'][i]['title'])
            recent_news.append(news)
            i += 1
        result_memory["recent_news"]=recent_news

    memory[task["id"]] = result_memory
    print(result_memory)

    for dep in task["depends_on"]:
        if dep not in memory:
            print(f"missing dependency for {task["task_id"]}")
            return None
    
        desc = f"execute {task['task_description']} using data {memory[dep]}"
        inputs.append(desc)
        print(inputs)
    

while len(completed) < len(tasks):
    for task in tasks:
        if task["id"] not in completed:
            print(task)
            if all(dep in completed for dep in task["depends_on"]):
                execute(task)
                completed.add(task["id"])

print(completed)

# %% [markdown]
# ### Get Tickter

# %%
import requests
import json

api_url = "https://finnhub.io/api/v1/search"

params = { 
    "q": "JPMorgan Chase & Co.",
    "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
}

response = requests.get(api_url,params=params).json()
print((response)['result'][0]['displaySymbol'])

# %% [markdown]
# ###  Closing price

# %%
import requests
import json

api_url = "https://finnhub.io/api/v1/quote"

params = { 
    "symbol": "JPM",
    "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
}

response = requests.get(api_url,params=params).json()
print((response)['c'])

# %% [markdown]
# ### News

# %%
url = "https://newsapi.org/v2/everything"
params = {
    "q":"JPM",
    "searchIn": "title",
    "apiKey": "7edafe2e5d804d59b16f305502fc5c54"
}

res = requests.get(url, params=params).json()
i=0
while i < 6:
    print(res['articles'][i]['title'])
    i += 1

# %%
for task in tasks:
    print((task['task_description'].lower()).split())

# %%
for dep in task['depends_on']:
        if dep not in memory:
            print(f"missing dependecy {dep} for task {task["id"]}")
            return None
        inputs.append(memory[dep])
            
    result = f"Task {task['id']} output using {inputs}"
    
    # print(f"Running task {task['id']}: {task['task_description']}")
    # print(f"Inputs = {inputs}")
    # print(f"Output = {result}\n")

    memory[task["id"]] = result 
    print(memory)

# %%
from google import genai
import re
import json
import requests

query = input()
memory = {}
recent_news = []
cache_price = []

def task_generator(query):
    prompt  = f""" 
    You are an AI Agent.

    Your job is to create a task list in JSON format 

    query: {query}
    
    From the given query you need to break the task in JSON format

    For each task provide:
    -id
    -task_description
    -depends_on (list of task ids)

    Rules:
    Tasks must be atomic 
    Dependencies must be logical 
    Avoid unneccessary dependecies 
    Allow parallel taks if possible
    Dont include tasks that require historical data

    Return only JSON

    Don't include:
    Markdowns
    text
    wildcards 
    explanations
    breaks

    """

    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )

    return (response.text)

def call_llm(prompt):
    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    res_llm = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )
    return (res_llm.text)   


tasks = json.loads(task_generator(user_query))

completed = set()


def get_ticker(task_description):
    prompt = f"""
        Extract the company name from the text.

        Return only the company name without a '.' at end
        No explanation.

            Text: {task_description}
        """
    company_name = (call_llm(prompt)).replace('.','')
    print(company_name)

    api_url = "https://finnhub.io/api/v1/search"

    params = { 
        "q": company_name,
        "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
    }

    resp = requests.get(api_url,params=params).json()
    memory["company_name"] = company_name
    memory["ticker"]=(resp)['result'][0]['displaySymbol']

def get_price(task_description):
    if "ticker" not in memory:
        get_ticker(task_description)
    api_url = "https://finnhub.io/api/v1/quote"

    params = { 
        "symbol": memory["ticker"],
        "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
    }

    resp_price = requests.get(api_url,params=params).json()
    memory["closing_price"]=(resp_price)['c']

def get_news(task_description):
    if "ticker" not in memory:
        get_ticker(task_description)
    url = "https://newsapi.org/v2/everything"
    params = {
        "q":memory["ticker"],
        "searchIn": "title",
        "apiKey": "7edafe2e5d804d59b16f305502fc5c54"
    }

    res = requests.get(url, params=params).json()
    i=0
    while i < 6:
        news = (res['articles'][i]['title'])
        recent_news.append(news)
        i += 1
    memory["recent_news"]=recent_news

def summarize(task_description):

    print("In summarize")
    if "company_name" not in memory:
        get_ticker(task_description)
    elif "closing_price" not in memory:
        get_price(task_description)
    elif "recent_news" not in memory:
        get_news(task_description)

    prompt = f'''
    Analyze the stock using:

    company_name:  {memory['company_name']}
    Price: {memory["closing_price"]}
    News: {memory["recent_news"]}
    

    Return in format:
    - Trend (up/down)
    - Sentiment (positive/negative)
    - 2 line summary
    '''

    summary = call_llm(prompt)
    print(summary)
    memory['summary'] = summary

def classify(task_desc):
    if "ticker" in task_desc:
        return get_ticker
    
    if "price" in task_desc:
        return get_price
    
    if "news" in task_desc:
        return get_news
    
    if "summary" in task_desc or "summarize" in task_desc:
        return summarize
    
    

while len(completed) < len(tasks):
    for task in tasks:
        if task["id"] not in completed:
            print(task)
            if all(dep in completed for dep in task["depends_on"]):
                execute_function = classify(task['task_description'])
                execute_function(task['task_description'])
                completed.add(task["id"])


print("\n=== FINAL OUTPUT ===")
print(f"ticker: {memory['ticker']}\n price: {memory['closing_price']} \n")
print(memory["summary"])

# %%
from google import genai
import re
import json
import requests

query = input('Proceed with your Query: ')
PRICE_KEYWORDS = ['price', 'trading', 'value', 'quote']
NEWS_KEYWORDS = ['news','update', 'happening', 'recent']
BUY_KEYWORDS = ['buy', 'invest','good', 'worth','analyse']
state = {
    'ticker': None,
    'price': None,
    'news': None 
}

def classify_with_llm(query):
    prompt = f'''
    Classify the query into:

    price
    news
    analysis
    none

    Return JSON ONLY:
    {{
      "needs_price": true/false,
      "needs_news": true/false,
      "needs_analysis": true/false
    }}

    Query: {query}
    '''
    response = llmcall(prompt)

    try:
        return (json.loads(response))
    except:
        return {
            "needs_price": False,
            "needs_news": False,
            "needs_analysis": False
        }

# Intent derival
def detect_intent(query):
    q = query.lower()

    intent = {
        "needs_price": any(word in q for word in PRICE_KEYWORDS),
        "needs_news": any(word in q for word in NEWS_KEYWORDS),
        "needs_analysis": any(word in q for word in BUY_KEYWORDS)
    }

    if not any(intent.values()):
        intent = classify_with_llm(query)

    return intent

COMPANY_MAP = {
    "infosys": "INFY",
    "tcs": "TCS",
    "reliance": "RELIANCE",
    "hdfc": "HDFCBANK"
}


# Entity derival 

def extract_ticker(query):
    q = query.lower()

    for name, ticker in COMPANY_MAP.items():
        if name in q:
            return ticker

    return (extract_with_llm(query))


def extract_with_llm(query):
    prompt = f"""
    Extract stock ticker from the query.
    Return only ticker.

    Don't include:
    Markdowns
    text
    wildcards 
    explanations
    breaks

    Query: {query}
    """

    return(llmcall(prompt))

def llmcall(prompt):
    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )

    return (response.text)

def is_stock_query(intent, ticker):
    return any(intent.values()) or ticker is not None

def check_state(query,state):
    intent = detect_intent(query)

    if not state['ticker']:
        state['ticker'] = extract_ticker(query)
    
    if not is_stock_query(intent, state['ticker']):
        print("Out of scope")
        exit()

    required = []

    if intent['needs_price'] or intent['needs_analysis']: 
        required.append('price')
    
    if intent['needs_news'] or intent['needs_analysis']:
        required.append('news')

    return required,intent

def execute_tool(req, state):
    for item in req:
        if item == 'price':
            state['price'] = get_price(state['ticker'])
        
        elif item == 'news':
            state['news'] = get_news(state['ticker'])


def get_price(ticker):

    if not ticker:
        raise Exception('Ticker missing for price fetch')

    api_url = "https://finnhub.io/api/v1/quote"

    params = { 
        "symbol": ticker,
        "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
    }

    resp_price = requests.get(api_url,params=params).json()
    return((resp_price)['c'])



def get_news(ticker):
    if not ticker:
        raise Exception('Ticker missing for news fetch')
    
    recent_news = []

    url = "https://newsapi.org/v2/everything"
    params = {
        "q":ticker,
        "searchIn": "title",
        "apiKey": "7edafe2e5d804d59b16f305502fc5c54"
    }

    res = requests.get(url, params=params).json()
    i=0
    while i < 6:
        news = (res['articles'][i]['title'])
        recent_news.append(news)
        i += 1
    
    return recent_news
    
def generate_output(state, intent):
    if intent['needs_price'] and not intent['needs_analysis']:
        if state['price'] != 0:
            return f"current price of {state['ticker']} is {state['price']}"
        else:
            return "invalid price"
    
    elif intent['needs_news'] and not intent['needs_analysis']:
        return f"Recent news for {state['ticker']}:\n" + "\n".join(state['news'])
    
    elif intent['needs_analysis']:
        prompt = f''' 
        Analyze the stock:

        Ticker: {state['ticker']}
        Price: {state['price']}
        News: {state['news']}

        Give a concise investment insight (max 5 lines). 
        '''

        return llmcall(prompt)

required,intent = check_state(query,state)
execute_tool(required,state)

print(state)
if state['ticker']:
    print(generate_output(state,intent))
else:
    print("Invalid stock specified")

# %%
from google import genai
import requests
import json
import re

query = input("I'm your financial assistant - please type in your financial queries")

PRICE_KEYWORDS = ['price', 'trading', 'value', 'quote']
NEWS_KEYWORDS = ['news','update', 'happening', 'recent']
BUY_KEYWORDS = ['buy', 'invest','good', 'worth','analyse']
state = {
    'ticker': None,
    'price': None,
    'news': None 
}

def cleanup_response(resp):
    resps = resp.strip()

    response = re.sub(r"```json|```", "", resps)
    return response.strip()

def classify_with_llm(query):
    prompt = f'''
    Classify the query into:

    price
    news
    analysis
    none

    Return JSON ONLY:
    {{
      "needs_price": true/false,
      "needs_news": true/false,
      "needs_analysis": true/false
    }}

    Query: {query}
    Don't include:
    Markdowns
    text
    wildcards 
    explanations
    breaks
    ```json



    '''
    raw_response = llmcall(prompt)
    response = cleanup_response(raw_response)

    try:
        return (json.loads(response))
    except:
        return {
            "needs_price": False,
            "needs_news": False,
            "needs_analysis": False
        }



# Intent derival
def detect_intent(query):
    q = query.lower()

    intent = {
        "needs_price": any(word in q for word in PRICE_KEYWORDS),
        "needs_news": any(word in q for word in NEWS_KEYWORDS),
        "needs_analysis": any(word in q for word in BUY_KEYWORDS)
    }

    if not any(intent.values()):
        intent = classify_with_llm(query)

    return intent
    
def llmcall(prompt):
    client = genai.Client(api_key='AIzaSyA5j1yn6Y7vsh2Va9wK9j_wOHL9mR3fbLA')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )

    return (response.text)


COMPANY_MAP = {
    "infosys": "INFY",
    "tcs": "TCS",
    "reliance": "RELIANCE",
    "hdfc": "HDFCBANK",
    "tesla":"TSLA"
}


# Entity derival 

def extract_ticker(query):
    q = query.lower()

    for name, ticker in COMPANY_MAP.items():
        if name in q:
            return ticker

    return (extract_with_llm(query))



def extract_with_llm(query):
    prompt = f"""
    Extract stock ticker from the query.
    Return only ticker.

    Don't include:
    Markdowns
    text
    wildcards 
    explanations
    breaks
    

    Query: {query}
    """

    return(llmcall(prompt))


def get_price(ticker):
    if not ticker:
        raise Exception('Ticker missing for price fetch')

    api_url = "https://finnhub.io/api/v1/quote"

    params = { 
        "symbol": ticker,
        "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
    }

    resp_price = requests.get(api_url,params=params).json()
    return((resp_price)['c'])



def get_news(ticker):
    if not ticker:
        raise Exception('Ticker missing for news fetch')
    
    recent_news = []

    url = "https://newsapi.org/v2/everything"
    params = {
        "q":ticker,
        "searchIn": "title",
        "apiKey": "7edafe2e5d804d59b16f305502fc5c54"
    }

    res = requests.get(url, params=params).json()
    i=0
    while i < 6:
        news = (res['articles'][i]['title'])
        recent_news.append(news)
        i += 1
    
    return recent_news

capabilities = {
    "price": get_price,
    "news": get_news
}

def is_stock_query(intent, ticker):
    return any(intent.values()) or ticker is not None

def check_state(query,state):
    intent = detect_intent(query)

    if not state['ticker']:
        state['ticker'] = extract_ticker(query)
    
    if not is_stock_query(intent, state['ticker']):
        print("Out of scope")
        return 

    required = []

    if intent['needs_price'] or intent['needs_analysis']: 
        required.append('price')
    
    if intent['needs_news'] or intent['needs_analysis']:
        required.append('news')

    return required,intent

def execute_tool(req,state):
    print(state['ticker'])
    print(req)
    for items in req:
        tool = capabilities.get(items)
        if tool:
            state[items] = tool(state['ticker'])

def get_mode(intent):
    if intent['needs_analysis']:
        return "analysis"
    if intent['needs_price']:
        return "price"
    if intent['needs_news']:
        return "news"

    return "none"

def validate_state(state):
    errors = []

    if state['ticker'] is None: 
        errors.append("missing_ticker")

    if state['price'] == 0: 
        errors.append("Invalid_price")
    
    if state['news'] is not None and len(state['news']) == 0:
        errors.append('empty_news')
    print(errors)
    return errors

def recover_state(errors, state):

    for error in errors:

        if error == 'Invalid_price':
            print('retrying to fetch price')
            state['price'] = get_price(state['ticker']) 

        elif error == 'empty_news':
            print('retrying fetching news')
            state['news'] = get_news(state['ticker'])

    return state 

def generate_output(state,mode):
    
    handlers = {
        "price": lambda: f"price of {state['ticker']} is {state['price']}" if state['price'] !=0 else f"Incorrect price output" ,
        "news": lambda: "News: \n" + "\n".join(state["news"]),
        "analysis": lambda: llmcall( f"""
        Analyze the stock:

        Ticker: {state['ticker']}
        Price: {state['price']}
        News: {state['news']}

        Give a concise investment insight (max 5 lines). 
        """),
        "none": lambda: "I handle only stock related queries"
    }

    handler = handlers.get(mode)

    if handler:
        return handler()
    
required,intent = check_state(query,state)
execute_tool(required,state)
errors = validate_state(state)

if errors: 
    state = recover_state(errors,state)

mode = get_mode(intent)
output = generate_output(state,mode)
print(output)

# %%
from google import genai
import requests
import sys
import json 
import re

memory = {}

query = input('Please free to type in your stock related queries')

PRICE_KEYWORDS = ['price', 'trading', 'value', 'quote']
NEWS_KEYWORDS = ['news','update', 'happening', 'recent']
BUY_KEYWORDS = ['buy', 'invest','good', 'worth','analyse']
COMPARISON_KEYWORDS = ['compare', 'comparison', 'difference', 'good', 'best', 'better']

def parsing_intent(query):
    intents = []
    if any (word in query for word in PRICE_KEYWORDS):
        intents.append('price')
    if any (word in query for word in NEWS_KEYWORDS):
        intents.append('news')
    if any(word in query for word in BUY_KEYWORDS):
        intents.append('analysis')
    
    return intents

def get_intent(query):
    q = query.lower()

    intent = {
        'compare': any(word in q for word in COMPARISON_KEYWORDS),
        'basis': parsing_intent(q),
    }

    return intent

entity = []

COMPANY_DB = {
    'apple': 'AAPL',
    'nvidia': 'NVDA',
    'jpmorgan': 'JPM',
    'google': 'GOOG',
    'microsoft': 'MSFT',
    'amazon': 'AMZN'
}

def entity_extraction(query):
    q = (query.lower()).split()

    entities = []


    for word in q:
        if word in COMPANY_DB:
            entity = {
                'ticker': COMPANY_DB[word],
                'price': None,
                'news': None
            }
            entities.append(entity)

    return entities


            
def check_required(query):
    intent = get_intent(query)
    entity = entity_extraction(query)

    if intent['compare'] and len(entity) < 2:
        print('compare can be done only for more than 1 companies')
        return "none","none"

    required = []
    
    if len(entity) == 0:
        return "none","none"

    if intent['basis']: 
        req = intent['basis']
    elif intent['compare']:
        req = ['price','news']
        intent['basis'] = req
    else:
        return "none","none"
        
    for enty in entity:
        new_req = {
            'entity': enty['ticker'],
            'needs': req
            }
        required.append(new_req)

    return required,intent

def api_call(ticker):
    
    if not ticker:
        raise Exception('Ticker missing for price fetch')

    api_url = "https://finnhub.io/api/v1/quote"

    params = { 
        "symbol": ticker,
        "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
    }

    try:
        resp_price = requests.get(api_url,params=params).json()
        return((resp_price)['c'])
    except Exception:
        print(f"get_price function exception: {Exception}")
        resp_price = 0
        return resp_price


def get_price(ticker):

    if ticker in memory and 'price' in memory[ticker]:
        return memory[ticker]['price']
    
    price = api_call(ticker)

    memory.setdefault(ticker, {})['price'] = price
    return price


def get_news(ticker):
    if not ticker:
        raise Exception('Ticker missing for news fetch')
    
    recent_news = []

    url = "https://newsapi.org/v2/everything"
    params = {
        "q":ticker,
        "searchIn": "title",
        "apiKey": "7edafe2e5d804d59b16f305502fc5c54"
    }


    try: 
        res = requests.get(url, params=params).json()
        i=0
        while i < 6:
            news = (res['articles'][i]['title'])
            recent_news.append(news)
            i += 1
        
        return recent_news
    except Exception:
        print(f'get_news function exception: {Exception}')
        return None 
    

capabilities = {
    "price": get_price,
    "news": get_news
}



def execute_tool(required):
    result_dict = {}
    for entries in required:
        try:
            key_val = entries['entity']
        except KeyError:
            print ('Function: execute_tool -KeyError')
            return {}
        except Exception:
            print(f'Function: execute_tool - {Exception}')
            return {}

        if key_val not in result_dict:
            result_dict[key_val] = {}
        
        needs = entries['needs']
        for item in needs:  
            tool = capabilities.get(item)
            if tool:
                try:
                    result_dict[key_val][item] = tool(key_val)
                except: 
                    return "none"

    return result_dict


def generate_output(result,intent):
    generated_output = []
    temp_word = ''
    is_both = False
    for ticker,info in result.items():

        if 'price' in intent['basis'] and 'news' in intent['basis']:
            temp_word = f"{ticker} - price is {info['price']} and news is {info['news']}" 
            is_both = True
        elif 'price' in intent['basis']:
            temp_word = f"price of {ticker} is {info['price']}"
        elif 'news' in intent['basis']:
            temp_word = f"news of ticker {ticker} is \n" +  "\n".join(info['news'])  
        elif 'analysis' in intent['basis']:
            temp_word = f"analyse stock {ticker} with its price {info['price']} and news {info['news']}"
        
        generated_output.append(temp_word)

    if intent['compare'] and set(intent['basis']) == {'price','news'}:
        prompt = f''' 
        You're a financial assistant.

        ONLY use the raw data below.
        DO NOT assume or add extra knowledge.

        Data:
        {generated_output}
        
        Task:
        compare and give best stock.

        Rules:
        Max 5 lines
        No Assumptions
        If data is insufficient, say "insufficient data" 
        '''
        final_output = llmcall(prompt)
    
    
    elif 'analysis' in intent['basis']:
        prompt = f''' 
        You're a financial assistant

        ONLY use raw data below. 
        DO NOT assume or add extra knowledge 

        Data: 
        {generated_output}
        
        Task:
        Analyze and give niche results 

        Rules:
        Max 5 lines
        No Assumptions
        If data is insufficient, say "insufficient data" 
        '''
        final_output = llmcall(prompt)
    
    else:
        final_output = '\n'.join(generated_output)

    return final_output
    

REQUIRED_STATE = {
    'price': lambda x: isinstance(x,(int,float)) and x>0,
    'news': lambda x: isinstance(x,list) and len(x) > 0
}

def validate_state(required, result):
    errors = []

    for req in required:
        err =  {}
        ticker = req['entity']
        needs = req['needs']

        entity_data = result.get(ticker, {})

        for need in needs:
            rule = REQUIRED_STATE.get(need)
            if rule:
                value = entity_data.get(need)

                try:
                    if not rule(value):
                        errors.append(
                            {
                                'ticker': ticker,
                                'field': need,
                                'error': 'invalid'
                            }
                        )
                except:
                    errors.append(
                        {
                            'ticker': ticker,
                            'field': need,
                            'error': 'exception'
                        }
                    )
        
    return errors 


def recover_state(result, errors):
    retry_count = {}

    for err in errors:
        ticker = err['ticker']
        field = err['field']

        key = f"{ticker}_{field}"
        retry_count[key] = retry_count.get(key,0) + 1

        if retry_count[key] > 1:
            continue

        tool = capabilities.get(field)

        if tool:
            try:
                result[ticker][field] = tool(ticker)
            except:
                continue
        
    return result

def llmcall(prompt):
    client = genai.Client(api_key='AIzaSyCYtDHF3PSaPKJ3IOCtUTKhoRaUHxhXAyo')
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents={"text": prompt}
    )

    return (response.text)
                    

required,intent = check_required(query)

if required == "none":
    sys.exit('please enter a stock related query')

result = execute_tool(required)
if len(result) == 0:
    sys.exit(f"Please understand the agent capability is limited - we are working on improving your experience. Please try another stock query")

MAX_RETRY = 3

for _ in range(MAX_RETRY):
    err = validate_state(required,result)

    if not err:
        break

    prev_result = result.copy()
    
    result = recover_state(result,err)

    if result == prev_result:
        break
    
if err:
    print(err)
    sys.exit()

print(generate_output(result,intent))
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[2], line 358
#     355     print(err)
#     356     sys.exit()
# --> 358 print(generate_output(result,intent))
#
# Cell In[2], line 227, in generate_output(result, intent)
#     209 if intent['compare'] and set(intent['basis']) == {'price','news'}:
#     210     prompt = f'''
#     211     You're a financial assistant.
#     212
#    (...)    225     If data is insufficient, say "insufficient data"
#     226     '''
# --> 227     final_output = llmcall(prompt)
#     230 elif 'analysis' in intent['basis']:
#     231     prompt = f'''
#     232     You're a financial assistant
#     233
#    (...)    246     If data is insufficient, say "insufficient data"
#     247     '''
#
# Cell In[2], line 322, in llmcall(prompt)
#     320 def llmcall(prompt):
#     321     client = genai.Client(api_key='AIzaSyCYtDHF3PSaPKJ3IOCtUTKhoRaUHxhXAyo')
# --> 322     response = client.models.generate_content(
#     323         model="gemini-2.5-flash",
#     324         contents={"text": prompt}
#     325     )
#     327     return (response.text)
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\google\genai\models.py:5621, in Models.generate_content(self, model, contents, config)
#    5619 while remaining_remote_calls_afc > 0:
#    5620   i += 1
# -> 5621   response = self._generate_content(
#    5622       model=model, contents=contents, config=parsed_config
#    5623   )
#    5625   function_map = _extra_utils.get_function_map(parsed_config)
#    5626   if not function_map:
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\google\genai\models.py:4283, in Models._generate_content(self, model, contents, config)
#    4280 request_dict = _common.convert_to_dict(request_dict)
#    4281 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4283 response = self._api_client.request(
#    4284     'post', path, request_dict, http_options
#    4285 )
#    4287 if config is not None and getattr(
#    4288     config, 'should_return_http_response', None
#    4289 ):
#    4290   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\google\genai\_api_client.py:1396, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1386 def request(
#    1387     self,
#    1388     http_method: str,
#    (...)   1391     http_options: Optional[HttpOptionsOrDict] = None,
#    1392 ) -> SdkHttpResponse:
#    1393   http_request = self._build_request(
#    1394       http_method, path, request_dict, http_options
#    1395   )
# -> 1396   response = self._request(http_request, http_options, stream=False)
#    1397   response_body = (
#    1398       response.response_stream[0] if response.response_stream else ''
#    1399   )
#    1400   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\google\genai\_api_client.py:1232, in BaseApiClient._request(self, http_request, http_options, stream)
#    1229     retry = tenacity.Retrying(**retry_kwargs)
#    1230     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1232 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\google\genai\_api_client.py:1209, in BaseApiClient._request_once(self, http_request, stream)
#    1201 else:
#    1202   response = self._httpx_client.request(
#    1203       method=http_request.method,
#    1204       url=http_request.url,
#    (...)   1207       timeout=http_request.timeout,
#    1208   )
# -> 1209   errors.APIError.raise_for_response(response)
#    1210   return HttpResponse(
#    1211       response.headers, response if stream else [response.text]
#    1212   )
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     131 else:
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\karth\OneDrive\Documents\1 - Data Science\000 - Data Analyst Bootcamp Practice\python\venv\Lib\site-packages\google\genai\errors.py:161, in APIError.raise_error(cls, status_code, response_json, response)
#     159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
# --> 161   raise ServerError(status_code, response_json, response)
#     162 else:
#     163   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
def read_user_query_file():
    try: 
        with open('user_query.json','r') as file:
            try: 
                data = json.load(file)
                return data
            except Exception as ex_json_read_error:
                print(f'ERROR: JSON read failed for user map - {ex_json_read_error}')
    except FileNotFoundError:
        with open('user_query.json', 'w') as file:
            file.write({})
            return {}
    except Exception as ex_user_file:
        print(f'ERROR: user_query.json file open failed - {ex_user_file}')
        return {}

def normalize(text):
    return text.lower().strip()

def user_token_log(entity,score,match,logic):
    user_query_log = read_user_query_file()

    word = normalize(entity)

    if word in user_query_log.keys():
        items = user_query_log[word]
        items["count"] += 1
        items["confidence"] = int(
            (items["confidence"] * (items["count"] - 1) + score)/items["count"]
        )
    else:
        user_query_log[word] = {
            "resolved": match,
            "confidence": score,
            "source": logic,
            "count": 1
        }
        

def check_required(query):
    intent = get_intent(query)
    entity = entity_extraction(query)

    
    if len(entity) == 0:
        call_llm = True
    elif intent['compare'] and len(entity) < 2:
        call_llm = True
    elif 'analysis' in intent['basis'] and len(entity) < 1:
        call_llm = True
    else:
        call_llm = False

    if call_llm: 
        print("LOG: Fuzzy extraction insufficient --> Triggering LLM")
        prompt = f'''
            Extract stock entities from the query.

            Query: {query}

            Return STRICT JSON:

            {{
            "entities": [
                {{
                "input": "appl",
                "resolved": "AAPL", 
                "confidence": 0.7
                }}
            ]
            }}

            Rules:
            - "input" = exact word/phrase from query
            - confidence = your certainty (0 to 1)
            - If none:
            {{"entities": []}}
            - this entities should contain only stock related word
            - Stops words shall be ignored in entities

            NO extra text.
        '''
        
        try:
            resp = re.sub(r"```json|```", "", llmcall(prompt))
            print(resp)
            data = json.loads(resp)["entities"]

            list_of_entities = []
            try:
                for items in data:
                    user_token_log(entity = items["input"],
                                match = items["resolved"],
                                score = int(items["confidence"] * 100),
                                logic = 'llm')
                    list_of_entities.append(items["resolved"])
            except KeyError:
                print(f'ERROR: Clean prompt the response is {resp}')
            except Exception as ex_entity_error:
                print(f'ERROR: in llm_call to log user query = {ex_entity_error}')

            response = {
                "tickers": list_of_entities
            }
            

        except Exception as ex1:
            print(f'LLM response JSON load failed  - Exception is {ex1}')

        try:
            if len(response['tickers']) == 0: 
                print(f'Please enter a stock related query')
                # sys.exit()
        except Exception as ex2:
            print(f'Exception occured during validation of entity extraction - {ex2}')
            # sys.exit()


        
        company_names = response['tickers']
        new_entries = []

        for ticker in company_names:
            exists = False 
            for items in entity:
                if ticker == items['ticker']:
                    exists = True
            
            if not exists:
                new_entity = {
                    'ticker': ticker,
                    'price': None,
                    'news': None,
                    'financials': None
                }
                new_entries.append(new_entity)


        entity.extend(new_entries)
    
    if len(entity) == 0:
        return "none","none"

    required = []
    req = plan_tools(intent, entity)
    
    if intent['compare']:
        intent['basis'] = req
        
    for enty in entity:
        new_req = {
            'entity': enty['ticker'],
            'needs': req
            }
        required.append(new_req)
 
    return required,intent

def plan_tools(intent, entity):

    plan = []

    if intent['compare']:
        plan = ['price','news','financials']
    
    elif "analysis" in intent['basis']:
        plan = ['financials']

        if len(entity) == 1:
            plan.append('news')
            plan.append('price')        

    elif 'price' in intent['basis']:
        plan.append('price')
    
    elif 'news' in intent['basis']:
        plan.append('news') 

    
    return plan

query = input('Please free to type in your stock related queries')
required,intent = check_required(query)
print(required)
print(intent)
# Out:
# [{'entity': 'AAPL', 'needs': ['price', 'news', 'financials']}, {'entity': 'AMZN', 'needs': ['price', 'news', 'financials']}]
# {'compare': True, 'basis': ['price', 'news', 'financials']}

# %%
import requests

EXACT_MATCH = {
    "assets": ["total assets"],
    "liabilities": ["total liabilities"],
    "cash": ["cash and cash equivalents"]
}

FALLBACK_API_URL = 'https://www.alphavantage.co/query'
FALL_API_KEY = 'D5UBRFGP3EKH7ROG'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:150.0) Gecko/20100101 Firefox/150.0'
    }

def fall_back_price(ticker):
    print(f"Falling back to secondary method for price for {ticker}")
    function = 'TIME_SERIES_DAILY'
    params = {
        'function': function,
        'symbol': ticker,
        'apikey': FALL_API_KEY
    }
    response = requests.get(FALLBACK_API_URL, params=params,  headers=HEADERS)
    fallback_price = response
    if response.status_code == 200:
        try:
            data = response.json()
            time_series = data.get('Time Series (Daily)', {})
            if time_series:
                latest_date = sorted(time_series.keys())[-1]
                fallback_price = time_series[latest_date]['4. close']
            else:
                print(f"No time series data found for {ticker} in fallback API.")
        except Exception as e:
            print(f"Error parsing fallback API response for {ticker}: {e}")

    return fallback_price


print(fall_back_price('AAPL'))
# Out:
# Falling back to secondary method for price for AAPL
# 298.9700
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
mem = {
    'appl':{
        '2026-05-21':{
            'news':'x',
            'price': 101
        }
    }
}

details = {
    'price': 120
}

ticker_dict = mem.setdefault('appl',{})
date_dict = ticker_dict.setdefault('appl',{})

date_dict.update(details)



# mem1 = mem.get('appl',{}).get('2026-05-21',{}).get('price', None)

print(mem1)
# Out:
# {'appl': {'2026-05-21': {'financials': {'debt_ratio': 1, 'debt': 100}}}}

# %%
import requests

FALL_BACK_EXACT_MATCH = {
    "assets": ["totalAssets"],
    "liabilities": ["totalLiabilities"],
    "cash": ["cashAndCashEquivalentsAtCarryingValue"]
}

FALLBACK_API_URL = 'https://www.alphavantage.co/query'
FALL_API_KEY = 'D5UBRFGP3EKH7ROG'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:150.0) Gecko/20100101 Firefox/150.0'
    }

def resolve_financial_term(term):
    for key, synonyms in FALL_BACK_EXACT_MATCH.items():
        if term in synonyms:
            return key
    return None

def fall_back_finance(ticker):
    print(f"Falling back to secondary method for finance data for {ticker}")
    function = 'BALANCE_SHEET'
    params = {
        'function': function,
        'symbol': ticker,
        'apikey': FALL_API_KEY
    }
    response = requests.get(FALLBACK_API_URL, params=params, headers=HEADERS)
    if response.status_code == 200:
        try:
            annual_reports = {}
            data = response.json()
            balance_sheet = data.get('annualReports', [])
            if len(balance_sheet) > 0:
                financials = max(balance_sheet, key=lambda x: x['fiscalDateEnding'])
                curr_year = financials['fiscalDateEnding'][:4]
                for key in financials:
                    resolved_term = resolve_financial_term(key)
                    if resolved_term:
                        annual_reports[resolved_term] = financials.get(key)

                financial_data = fall_back_compute_metrics(annual_reports)
            else:
                print(f"No time series data found for {ticker} in fallback API.")
        except Exception as e:
            print(f"Error parsing fallback API response for {ticker}: {e}")
            return {}

    return financial_data

def fall_back_compute_metrics(financials):
    
    assets = float(financials.get('assets', 0))
    liabilities = float(financials.get('liabilities', 0))
    cash = float(financials.get('cash', 0))

    try:
        debt_ratio = liabilities/assets
    except Exception as e:
        print(f"Error computing debt ratio: {e}")
        debt_ratio = 0
    
    return {
        "assets": assets,
        "liabilities": liabilities,
        "cash": cash,
        "debt_ratio": debt_ratio
    }


print(fall_back_finance('AAPL'))
# Out:
# Falling back to secondary method for finance data for AAPL
# {'assets': 359241000000.0, 'liabilities': 285508000000.0, 'cash': 35934000000.0, 'debt_ratio': 0.7947533828265705}

# %%
import requests
from datetime import datetime   
FALLBACK_API_URL = 'https://www.alphavantage.co/query'
FALL_API_KEY = 'D5UBRFGP3EKH7ROG'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:150.0) Gecko/20100101 Firefox/150.0'
    }


def fall_back_news(ticker):
    print(f"Falling back to secondary method for news for {ticker}")
    url = FALLBACK_API_URL
    params = {
        "function": "NEWS_SENTIMENT",
        "tickers": ticker,
        "apikey": FALL_API_KEY
    }

    try:
        res = requests.get(url, params=params).json()
        recent_news = []
        feed = res.get('feed', [])

        top_news = sorted(feed, key=lambda x: datetime.strptime(x['time_published'], '%Y%m%dT%H%M%S'), reverse=True)[:6]
        for items in top_news:
            recent_news.append(items['title'])

        return recent_news
    except Exception as e:
        print(f"Error fetching news from fallback API for {ticker}: {e}")
        return None
                   

fall_back_news('AAPL')
# Out:
# Falling back to secondary method for news for AAPL
# ["Apple climbs on earnings as China 'now a strong tailwind', says Wedbush",
#  'Comstock Holding (NASDAQ: CHCI) posts $62M FY2025 revenue; Reston Station delivers',
#  '367,556 Shares in Apple Inc. $AAPL Purchased by GLP Holdings LLLP',
#  'Reading International (NASDAQ: RDI) expands 2025 governance and pay disclosures',
#  'Silvaco Group Stockholders Reelect Board at Annual Meeting',
#  'Goldman Sachs raises Apple stock price target to $340 on demand']

# %%
FINANCIAL_REPORT_URL = "https://finnhub.io/api/v1/stock/financials-reported"
FINANCIAL_METRICS_NEEDED = {'Total assets', 'Total liabilities', 'Cash and cash equivalents', 'Accounts payable', 'Inventories','Total current liabilities'}

EXACT_MATCH = {
    "assets": ["total assets"],
    "liabilities": ["total liabilities"],
    "cash": ["cash and cash equivalents"]
}

FUZZY_MATCH = {
    "assets": [
        "assets, current",
        "assets total"
    ],
    "liabilities": [
        "liabilities, current",
        "total liabilities",
        "liabilities"
    ],
    "cash": [
        "cash equivalents",
    ]
}


BLACKLIST = ["other", "misc", "non-current"]


def get_financial_reports(ticker):
    annual_data = {}
    api_url = FINANCIAL_REPORT_URL
    response = api_call(ticker,api_url)
    try:
        if response == 'none':
            return annual_data
        else:
            data = response['data']
            current_data = max(data, key=lambda x: x['year'])
            curr_year = current_data['year']
            annual_data[curr_year] = {}
            reports = current_data['report']['bs']

            # for item in data: 
            #     curr_year = item['year']
            #     annual_data[curr_year] = {}
            #     reports = item['report']['bs']
            metric_store = {}
            for details in reports:
                key, score = resolve_metric(details['label'])
                if key:
                    print(f"Resolved {details['label']} to {key} with score {score}")
                    current = metric_store.get(key)
                    if current:
                        current_score = current.get('score', 0)
                    else:
                        current_score = 0

                    print(f"Key: {key}, Score: {score}, Current Score: {current_score}")
                    if not current or score > current_score:
                        metric_store[key] = {
                            "value": details['value'],
                            "score": score,
                            "label": details["label"]
                        }
                print(metric_store)

            annual_data[curr_year] = {
                k: v['value'] for k, v in metric_store.items()
            }

    except Exception as ex3:
        print(f"get_financial_report function exception: {ex3}")
        return annual_data

    financial_data = compute_metrics(annual_data,curr_year)
    return financial_data

def api_call(ticker,url):
    
    if not ticker:
        raise Exception('Ticker missing for price fetch')

    api_url = url

    params = { 
        "symbol": ticker,
        "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
    }

    try:
        response = requests.get(api_url,params=params).json()
        return(response)
    except Exception as ex1:
        print(f"api call failed exception: {ex1}")
        response = 'none'
        return response


def resolve_metric(input):
    label = normalize(input)

    if any(b in label for b in BLACKLIST):
        return None, 0
    

    for key,phrases in EXACT_MATCH.items():

        if any(p == label for p in phrases):
            return key,3
    
    for key,phrases in FUZZY_MATCH.items():

        if any(p in label for p in phrases):
            return key,2
        

    return None,0

def compute_metrics(financials,year):
    
    assets = financials[year].get('assets', 0)
    liabilities = financials[year].get('liabilities', 0)
    cash = financials[year].get('cash', 0)

    try:
        debt_ratio = liabilities/assets
    except:
        debt_ratio = 0
    
    return {
        "assets": assets,
        "liabilities": liabilities,
        "cash": cash,
        "debt_ratio": debt_ratio
    }

def normalize(text):
    return text.lower().strip()

print(get_financial_reports('AAPL'))
# Out:
# Resolved Cash and cash equivalents to cash with score 3
# Key: cash, Score: 3, Current Score: 0
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}}
# Resolved Total assets to assets with score 3
# Key: assets, Score: 3, Current Score: 0
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}}
# Resolved Total current liabilities to liabilities with score 2
# Key: liabilities, Score: 2, Current Score: 0
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 165631000000, 'score': 2, 'label': 'Total current liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 165631000000, 'score': 2, 'label': 'Total current liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 165631000000, 'score': 2, 'label': 'Total current liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 165631000000, 'score': 2, 'label': 'Total current liabilities'}}
# Resolved Total liabilities to liabilities with score 3
# Key: liabilities, Score: 3, Current Score: 2
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
# Resolved Total liabilities and shareholders’ equity to liabilities with score 2
# Key: liabilities, Score: 2, Current Score: 3
# {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
# {'assets': 359241000000, 'liabilities': 285508000000, 'cash': 35934000000.0, 'debt_ratio': 0.7947533828265705}

# %%
metric_score = {'cash': {'value': 35934000000.0, 'score': 3, 'label': 'Cash and cash equivalents'}, 'assets': {'value': 359241000000, 'score': 3, 'label': 'Total assets'}, 'liabilities': {'value': 285508000000, 'score': 3, 'label': 'Total liabilities'}}
res = metric_score.get('liabilities ', {})
print(res)
# Out:
# {}

# %%
# %pip install rapidfuzz

# %%
# %pip install anthropic

# %%
from rapidfuzz import process 
from google import genai
import anthropic 
import requests
import sys
import json 
import re

memory = {}

user_query_mem = {}

STOP_WORDS = ['compare', 'or', 'and', 'of', 'are', 'vs' ,'what']

PRICE_API_URL = "https://finnhub.io/api/v1/quote"
FINANCIAL_REPORT_URL = "https://finnhub.io/api/v1/stock/financials-reported"
FINANCIAL_METRICS_NEEDED = {'Total assets', 'Total liabilities', 'Cash and cash equivalents', 'Accounts payable', 'Inventories','Total current liabilities'}


BLACKLIST = ["other", "misc", "non-current"]


EXACT_MATCH = {
    "assets": ["total assets"],
    "liabilities": ["total liabilities"],
    "cash": ["cash and cash equivalents"]
}

FUZZY_MATCH = {
    "assets": [
        "assets, current",
        "assets total"
    ],
    "liabilities": [
        "liabilities, current",
        "total liabilities",
        "liabilities"
    ],
    "cash": [
        "cash equivalents",
    ]
}

query = input('Please free to type in your stock related queries')

PRICE_KEYWORDS = ['price', 'trading', 'value', 'quote']
NEWS_KEYWORDS = ['news','update', 'happening', 'recent']
BUY_KEYWORDS = ['buy', 'invest','good', 'worth','analyse']
COMPARISON_KEYWORDS = ['compare', 'comparison', 'difference', 'good', 'best', 'better']

def parsing_intent(query):
    intents = []
    if any (word in query for word in PRICE_KEYWORDS):
        intents.append('price')
    if any (word in query for word in NEWS_KEYWORDS):
        intents.append('news')
    if any(word in query for word in BUY_KEYWORDS):
        intents.append('analysis')
    
    return intents

def get_intent(query):
    q = query.lower()

    intent = {
        'compare': any(word in q for word in COMPARISON_KEYWORDS),
        'basis': parsing_intent(q),
    }

    return intent

entity = []

ALIAS_MAP = {}

try:
    with open('alias_map.json','r') as file:

        try:
            ALIAS_MAP = json.load(file)
        except Exception as ex_json:
            print(f'ERROR: Error while loading ALIAS_MAP check {file} for exception {ex_json}')
except FileNotFoundError:
     print(f'ERROR: alias_map.json file not found - creation a new one')
     with open('alias_map.json','w') as file:
         file.write(ALIAS_MAP)

except Exception as ex_file_error:
    print(f'ERROR: error while opening alias_map.json file - {ex_file_error}')

COMPANY_DB = {
    'apple': 'AAPL',
    'nvidia': 'NVDA',
    'jpmorgan': 'JPM',
    'google': 'GOOG',
    'microsoft': 'MSFT',
    'amazon': 'AMZN'
}

def fuzzy_match(word, choices):
    match, score, _ = process.extractOne(word,choices)
    print (f"LOG: Token {word}, match: {match}, score: {score}")
    if score >= 80:
        logic = 'fuzzy'
        return match, logic, score
    
    return None

def user_token_log(entity,score,match,logic):
    user_query_log = read_user_query_file()

    word = normalize(entity)

    if word in user_query_log.keys():
        items = user_query_log[word]
        items["count"] += 1
        items["confidence"] = int(
            (items["confidence"] * (items["count"] - 1) + score)/items["count"]
        )
    else:
        user_query_log[word] = {
            "resolved": match,
            "confidence": score,
            "source": logic,
            "count": 1
        }
        
    write_user_query_file(user_query_log)

def read_user_query_file():
    try: 
        with open('user_query.json','r') as file:
            try: 
                data = json.load(file)
                return data
            except Exception as ex_json_read_error:
                print(f'ERROR: JSON read failed for user map - {ex_json_read_error}')
    except FileNotFoundError:
        with open('user_query.json', 'w') as file:
            file.write({})
            return {}
    except Exception as ex_user_file:
        print(f'ERROR: user_query.json file open failed - {ex_user_file}')
        return {}

def write_user_query_file(data):
    try:
        with open('user_query.json','w') as file:
            json.dump(data, file, indent=4)
    except Exception as ex_write_user_json:
        print(f'ERROR: while writing user_query.json file - {ex_write_user_json}')



def entity_extraction(query):
    seen = set()
    words = re.findall(r'\b\w+\b', query.lower())
    tokens = [word for word in words if word not in STOP_WORDS]
    entities = []


    for token in tokens:

        if len(token) > 3:
            company_name,logic,score = fuzzy_match(token,COMPANY_DB.keys())

            if not company_name:
                company_name,logic,score = fuzzy_match(token,ALIAS_MAP.keys())

            if  company_name:
                if company_name in ALIAS_MAP:
                    ticker = ALIAS_MAP[company_name]
                elif company_name in COMPANY_DB:
                    ticker = COMPANY_DB[company_name]

                user_token_log(token,score,ticker,logic)

                if ticker not in seen:

                    entity = {
                        'ticker': ticker,
                        'price': None,
                        'news': None,
                        'financials': None
                    }
                    seen.add(ticker)
                    entities.append(entity)
            

    return entities


def normalize(text):
    return text.lower().strip()

def llmcall(prompt):
    client = genai.Client(api_key='AIzaSyBXxSjUUjhw9n8F1NFQXIfFf51sv6RA_EU')
    response = client.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents={"text": prompt}
    )

    return (response.text)
                    

def check_required(query):
    intent = get_intent(query)
    entity = entity_extraction(query)

    
    if len(entity) == 0:
        call_llm = True
    elif intent['compare'] and len(entity) < 2:
        call_llm = True
    elif 'analysis' in intent['basis'] and len(entity) < 1:
        call_llm = True
    else:
        call_llm = False

    if call_llm: 
        print("LOG: Fuzzy extraction insufficient --> Triggering LLM")
        prompt = f'''
            Extract stock entities from the query.

            Query: {query}

            Return STRICT JSON:

            {{
            "entities": [
                {{
                "input": "appl",
                "resolved": "AAPL", 
                "confidence": 0.7
                }}
            ]
            }}

            Rules:
            - "input" = exact word/phrase from query
            - confidence = your certainty (0 to 1)
            - If none:
            {{"entities": []}}
            - this entities should contain only stock related word
            - Stops words shall be ignored in entities

            NO extra text.
        '''
        
        try:
            resp = re.sub(r"```json|```", "", llmcall(prompt))
            print(resp)
            data = json.loads(resp)["entities"]

            list_of_entities = []
            try:
                for items in data:
                    user_token_log(entity = items["input"],
                                match = items["resolved"],
                                score = int(items["confidence"] * 100),
                                logic = 'llm')
                    list_of_entities.append(items["resolved"])
            except KeyError:
                print(f'ERROR: Clean prompt the response is {resp}')
            except Exception as ex_entity_error:
                print(f'ERROR: in llm_call to log user query = {ex_entity_error}')

            response = {
                "tickers": list_of_entities
            }
            

        except Exception as ex1:
            print(f'LLM response JSON load failed  - Exception is {ex1}')

        try:
            if len(response['tickers']) == 0: 
                print(f'Please enter a stock related query')
                sys.exit()
        except Exception as ex2:
            print(f'Exception occured during validation of entity extraction - {ex2}')
            sys.exit()


        
        company_names = response['tickers']
        new_entries = []

        for ticker in company_names:
            exists = False 
            for items in entity:
                if ticker == items['ticker']:
                    exists = True
            
            if not exists:
                new_entity = {
                    'ticker': ticker,
                    'price': None,
                    'news': None,
                    'financials': None
                }
                new_entries.append(new_entity)


        entity.extend(new_entries)

    required = []
    
    if len(entity) == 0:
        return "none","none"

    if intent['basis']: 
        if "analysis" in intent['basis']:
            req=['price','news','financials']
        else:
            req = intent['basis']
    elif intent['compare']:
        req = ['price','news','financials']
        intent['basis'] = req
    else:
        return "none","none"
        
    for enty in entity:
        new_req = {
            'entity': enty['ticker'],
            'needs': req
            }
        required.append(new_req)

    return required,intent

def api_call(ticker,url):
    
    if not ticker:
        raise Exception('Ticker missing for price fetch')

    api_url = url

    params = { 
        "symbol": ticker,
        "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
    }

    try:
        response = requests.get(api_url,params=params).json()
        return(response)
    except Exception as ex1:
        print(f"api call failed exception: {ex1}")
        response = 'none'
        return response
    


def get_price(ticker):

    if ticker in memory and 'price' in memory[ticker]:
        return memory[ticker]['price']
    
    api_url = PRICE_API_URL

    response = api_call(ticker,api_url)
    try:
        if response == 'none':
            price = 0
        else:
            price = response['c']
    except Exception as ex2:
        print(f"get_price function exception: {ex2}")
        price = 0

    memory.setdefault(ticker, {})['price'] = price
    return price


def get_news(ticker):
    if not ticker:
        raise Exception('Ticker missing for news fetch')
    
    recent_news = []

    url = "https://newsapi.org/v2/everything"
    params = {
        "q":ticker,
        "searchIn": "title",
        "apiKey": "7edafe2e5d804d59b16f305502fc5c54"
    }


    try: 
        res = requests.get(url, params=params).json()
        i=0
        while i < 6:
            news = (res['articles'][i]['title'])
            recent_news.append(news)
            i += 1
        
        return recent_news
    except Exception as ex3:
        print(f'get_news function exception: {ex3}')
        return None 
    
def get_financial_reports(ticker):
    if ticker in memory and 'financials' in memory[ticker]:
        return memory[ticker]['financials']
    annual_data = {}
    api_url = FINANCIAL_REPORT_URL
    response = api_call(ticker,api_url)
    try:
        if response == 'none':
            return annual_data
        else:
            data = response['data']
            current_data = max(data, key=lambda x: x['year'])
            curr_year = current_data['year']
            annual_data[curr_year] = {}
            reports = current_data['report']['bs']

            # for item in data: 
            #     curr_year = item['year']
            #     annual_data[curr_year] = {}
            #     reports = item['report']['bs']
            metric_store = {}
            for details in reports:
                key, score = resolve_metric(details['label'])
                if key:
                    current = metric_store.get(key)
                    current_score = metric_store.get('score', 0)
                    if not current or score > current_score:
                        metric_store[key] = {
                            "value": details['value'],
                            "score": score,
                            "label": details["label"]
                        }
                    

            annual_data[curr_year] = {
                k: v['value'] for k, v in metric_store.items()
            }

    except Exception as ex3:
        print(f"get_financial_report function exception: {ex3}")
        return annual_data

    financial_data = compute_metrics(annual_data,curr_year)

    memory.setdefault(ticker, {})['financials'] = financial_data
    return financial_data

def resolve_metric(input):
    label = normalize(input)

    if any(b in label for b in BLACKLIST):
        return None, 0
    

    for key,phrases in EXACT_MATCH.items():

        if any(p == label for p in phrases):
            return key,3
    
    for key,phrases in FUZZY_MATCH.items():

        if any(p in label for p in phrases):
            return key,2
        

    return None,0

def compute_metrics(financials,year):
    
    assets = financials[year].get('assets', 0)
    liabilities = financials[year].get('liabilities', 0)
    cash = financials[year].get('cash', 0)

    try:
        debt_ratio = liabilities/assets
    except:
        debt_ratio = 0
    
    return {
        "assets": assets,
        "liabilities": liabilities,
        "cash": cash,
        "debt_ratio": debt_ratio
    }

capabilities = {
    "price": get_price,
    "news": get_news,
    "financials": get_financial_reports
}



def execute_tool(required):
    result_dict = {}
    for entries in required:
        try:
            key_val = entries['entity']
        except KeyError:
            print ('Function: execute_tool -KeyError')
            return {}
        except Exception:
            print(f'Function: execute_tool - {Exception}')
            return {}

        if key_val not in result_dict:
            result_dict[key_val] = {}
        
        needs = entries['needs']
        for item in needs:  
            tool = capabilities.get(item)
            if tool:
                try:
                    result_dict[key_val][item] = tool(key_val)
                except: 
                    return "none"

    return result_dict

def compute_confidence(financials):
    financial_confidence = 0

    if financials['assets']: financial_confidence += 1
    if financials['cash']: financial_confidence += 1
    if financials['debt_ratio']: financial_confidence += 1
    
    return financial_confidence

def generate_output(result,intent):
    generated_output = []
    temp_word = ''
    for ticker,info in result.items():

        if ('price' in intent['basis'] and 'news' in intent['basis'] and 'financials' in intent['basis']) or 'analysis' in intent['basis']:
            financial_confidence = compute_confidence(info['financials'])
            temp_word = f"""
            {ticker}:
             - price: {info['price']} 
             - cash: {info['financials']['cash']}
             - Debt ratio: {info['financials']['debt_ratio']}
             - Assets: {info['financials']['assets']}
             - news: {info['news']} 

             - financial confidence = {financial_confidence}
            """

        elif 'price' in intent['basis']:
            temp_word = f"price of {ticker} is {info['price']}"
        elif 'news' in intent['basis']:
            temp_word = f"news of ticker {ticker} is \n" +  "\n".join(info['news'])  

        generated_output.append(temp_word)

    if intent['compare'] and set(intent['basis']) == {'price','news','financials'}:
        prompt = f''' 
        You're a financial assistant.

        ONLY use the raw data below.
        DO NOT assume or add extra knowledge.

        Data:
        {generated_output}
        
        Task:
        Compare the stocks based ONLY on:

        1. Financial strength (debt ratio, cash)
        2. Current price (relative valuation hint)
        3. News sentiment

        Rules:
        - If one stock clearly stronger → choose it
        - If mixed signals → say "no clear winner"
        - Do NOT default to insufficient unless truly missing
        No Assumptions
        '''
        final_output = llmcall(prompt)
    
    
    elif 'analysis' in intent['basis']:
        prompt = f''' 
        You're a financial assistant

        ONLY use raw data below. 
        DO NOT assume or add extra knowledge 

        Data: 
        {generated_output}
        
        Task:
        Analyze and give niche results 

        Rules:
        Max 5 lines
        No Assumptions
        If data is insufficient, say "insufficient data" 
        '''
        final_output = llmcall(prompt)
    
    else:
        final_output = '\n'.join(generated_output)

    return final_output
    
def validate_financials(financials):
    if not isinstance(financials,dict):
        return False
    
    required_key_fields = ['assets','liabilities','cash','debt_ratio']

    for key in required_key_fields:
        if key not in financials:
            return False
    
    if financials['assets'] <= 0:
        return False
    
    if financials['liabilities'] < 0:
        return False
    
    if financials['cash'] < 0:
        return False
    
    if financials['debt_ratio'] < 0:
        return False
    
    return True



REQUIRED_STATE = {
    'price': lambda x: isinstance(x,(int,float)) and x>0,
    'news': lambda x: isinstance(x,list) and len(x) > 0,
    'financials': lambda x:validate_financials(x)
}

def validate_state(required, result):
    errors = []

    for req in required:
        ticker = req['entity']
        needs = req['needs']

        entity_data = result.get(ticker, {})

        for need in needs:
            rule = REQUIRED_STATE.get(need)
            if rule:
                value = entity_data.get(need)

                try:
                    if not rule(value):
                        errors.append(
                            {
                                'ticker': ticker,
                                'field': need,
                                'error': 'invalid'
                            }
                        )
                except:
                    errors.append(
                        {
                            'ticker': ticker,
                            'field': need,
                            'error': 'exception'
                        }
                    )
        
    return errors 


def recover_state(result, errors):
    retry_count = {}

    for err in errors:
        ticker = err['ticker']
        field = err['field']

        key = f"{ticker}_{field}"
        retry_count[key] = retry_count.get(key,0) + 1

        if retry_count[key] > 1:
            continue

        tool = capabilities.get(field)

        if tool:
            try:
                result[ticker][field] = tool(ticker)
            except:
                continue
        
    return result

def llmcall(prompt):
    client = genai.Client(api_key='AIzaSyBXxSjUUjhw9n8F1NFQXIfFf51sv6RA_EU')
    response = client.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents={"text": prompt}
    )

    return (response.text)

def promotion_to_alias():
    try:
        with open('user_query.json','r') as file:
            user_data = json.load(file) 
    except Exception as ex_read_user_query_file:
        print(f'ERROR: Opening user_query.json in promotion_to_alias function - {ex_read_user_query_file}')
        return
    try:
        with open('alias_map.json','r') as file:
            alias_data = json.load(file)
    except Exception as ex_read_alias_map_file:
        print(f'ERROR: Opening alias_map.json in promotion_to_alias function - {ex_read_alias_map_file}')
        return


    updated = False

    for query,info in user_data.items():
        if info['count'] >= 3 and info['confidence'] >= 80:
            resolved = info['resolved']

            if query not in alias_data:
                alias_data[query] = resolved
                print(f"PROMOTION: {query} → {resolved}")
                updated = True
        
    if updated:
        try:
            with open('alias_map.json','w') as f:
                json.dump(alias_data,f,indent=4)
        except Exception as ex_write_alias:
            print(f'LOG: promotion to alias failed and reason is {ex_write_alias}')

required,intent = check_required(query)

if required == "none":
    sys.exit('please enter a stock related query')

result = execute_tool(required)
if len(result) == 0:
    sys.exit(f"Please understand the agent capability is limited - we are working on improving your experience. Please try another stock query")

MAX_RETRY = 3

for _ in range(MAX_RETRY):
    err = validate_state(required,result)

    if not err:
        break

    prev_result = result.copy()
    
    result = recover_state(result,err)

    if result == prev_result:
        break
    
if err:
    print(err)
    sys.exit()

print(generate_output(result,intent))

promotion_to_alias()
# Out:
# LOG: Token amazn, match: amazon, score: 90.9090909090909
# LOG: Token microsft, match: microsoft, score: 94.11764705882352
# **Financial Strength:**
#
# *   **Debt Ratio:** AMZN has a debt ratio of 1.0, while MSFT has a debt ratio of 3.2386. A lower debt ratio generally indicates better financial strength.
# *   **Cash:** AMZN has $86,810,000,000 in cash, and MSFT has $94,565,000,000 in cash. MSFT has more cash on hand.
#
# **Current Price:**
#
# *   AMZN: $263.99
# *   MSFT: $424.62
#
# **News Sentiment:**
#
# *   **AMZN:** News includes "Better Magnificent 7 Stock to Buy?", "Expands Partnership", "Advances AI and Satellite Expansion Plans", "Lucrative Investment Opportunity?", "Top AI Stock Pick", "Top High-Flying AI Stock to Buy". This suggests generally positive sentiment.
# *   **MSFT:** News includes "Price Target Lowered", "Warning: Why Piper Sandler Analysts Just Slashed Their MSFT Price Target", "Israel Englander Trims Position", "Will AI Disruption Crush?", "What Hurt Microsoft’s AI Positioning", "Jim Cramer Makes Big Claim". This suggests mixed to negative sentiment.
#
# **Comparison:**
#
# AMZN shows stronger financial strength with a significantly lower debt ratio. While MSFT has more cash, AMZN's debt ratio is a more critical indicator of financial stability. The news sentiment for AMZN appears more positive and growth-oriented, while MSFT's news includes several cautionary notes and analyst downgrades.
#
# **Winner:** AMZN

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\karth\onedrive\documents\1 - data science\000 - data analyst bootcamp practice\python\venv\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\karth\onedrive\documents\1 - data science\000 - data analyst bootcamp practice\python\venv\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karth\onedrive\documents\1 - data science\000 - data analyst bootcamp practice\python\venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karth\onedrive\documents\1 - data science\000 - data analyst bootcamp practice\python\venv\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karth\onedrive\documents\1 - data science\000 - data analyst bootcamp practice\python\venv\lib\site-packages (from requests) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
memory.clear()

# %%
def promotion_to_alias():
    with open('user_query.json','r') as file:
        user_data = json.load(file)
    
    with open('alias_map.json','r') as file:
        alias_data = json.load(file)

    updated = False

    for query,info in user_data.items():
        if info['count'] >= 3 and info['confidence'] >= 80:
            resolved = info['resolved']

        if query not in alias_data:
            alias_data[query] = resolved
            updated = True
    
    if updated:
        with open('alias_map.json','w') as f:
            json.dump(alias_data,f,indent=4)

promotion_to_alias()

# %%
data = {
            "entitiies": [
                {
                "input": "appl",
                "resolved": "AAPL", 
                "confidence": 0.7
                },
                {
                "input": "amzn",
                "resolved": "AMZN", 
                "confidence": 0.7
                }
            ] 
        }

entities = []
for items in data['entitiies']:
    entity = items['resolved']
    entities.append(entity)


print(entities)
# Out:
# ['AAPL', 'AMZN']

# %%
with open('user_query.json', 'r', encoding='utf-8') as f:
    content = f.read()
    print(f"File content: '{content}'") # Check if this is empty or malformed
    data = json.loads(content)
    print(data)
# Out:
# File content: '{}'
# {}

# %%
BLACKLIST = ["other", "misc", "non-current"]


EXACT_MATCH = {
    "assets": ["total assets"],
    "liabilities": ["total liabilities"],
    "cash": ["cash and cash equivalents"]
}

FUZZY_MATCH = {
    "assets": [
        "assets, current",
        "assets total"
    ],
    "liabilities": [
        "liabilities, current",
        "total liabilities",
        "liabilities"
    ],
    "cash": [
        "cash equivalents",
    ]
}

def resolve_metric(input):
    label = normalize(input)

    if any(b in label for b in BLACKLIST):
        return None, 0
    


    for key,phrases in EXACT_MATCH.items():

        if any(p == label for p in phrases):
            return key,3
    
    for key,phrases in FUZZY_MATCH.items():

        if any(p in label for p in phrases):
            return key,2
        

    return None,0


def get_financial_reports(ticker):
    print(memory)
    if ticker in memory and 'financials' in memory[ticker]:
        return memory[ticker]['financials']
    annual_data = {}
    api_url = FINANCIAL_REPORT_URL
    response = api_call(ticker,api_url)
    print(response)
    try:
        if response == 'none':
            return annual_data
        else:
            data = response['data']
            current_data = max(data, key=lambda x: x['year'])
    
            curr_year = current_data['year']
            annual_data[curr_year] = {}
            reports = current_data['report']['bs']
            # for item in data: 
            #     curr_year = item['year']
            #     annual_data[curr_year] = {}
            #     reports = item['report']['bs']
            metric_store = {}
            for details in reports:
                key, score = resolve_metric(details['label'])
                if key:
                    current = metric_store.get(key)
                    current_score = metric_store.get('score', 0)
                    if not current or score > current_score:
                        metric_store[key] = {
                            "value": details['value'],
                            "score": score,
                            "label": details["label"]
                        }
                    

            annual_data[curr_year] = {
                k: v['value'] for k, v in metric_store.items()
            }

    except Exception as ex3:
        print(f"get_financial_report function exception: {ex3}")
        return annual_data
    
    print(f'annual_data : {annual_data}')

    financial_data = compute_metrics(annual_data,curr_year)
    memory.setdefault(ticker, {})['financials'] = financial_data
    return financial_data


data = get_financial_reports('MSFT')

print(f'Finanal financial data {data}')
# Out:
# {}
# {'cik': '789019', 'data': [{'accessNumber': '0000950170-25-100235', 'symbol': 'MSFT', 'cik': '789019', 'year': 2025, 'quarter': 0, 'form': '10-K', 'startDate': '2024-07-01 00:00:00', 'endDate': '2025-06-30 00:00:00', 'filedDate': '2025-07-30 00:00:00', 'acceptedDate': '2025-07-30 16:11:40', 'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue', 'unit': 'u_usd', 'label': 'Cash and Cash Equivalents, at Carrying Value', 'value': 30242000000.0}, {'concept': 'us-gaap_ShortTermInvestments', 'unit': 'u_usd', 'label': 'Short-Term Investments', 'value': 64323000000.0}, {'concept': 'us-gaap_CashCashEquivalentsAndShortTermInvestments', 'unit': 'u_usd', 'label': 'Cash, Cash Equivalents, and Short-Term Investments', 'value': 94565000000}, {'concept': 'us-gaap_AccountsReceivableNetCurrent', 'unit': 'u_usd', 'label': 'Accounts Receivable, after Allowance for Credit Loss, Current', 'value': 69905000000}, {'concept': 'us-gaap_InventoryNet', 'unit': 'u_usd', 'label': 'Inventory, Net', 'value': 938000000}, {'concept': 'us-gaap_OtherAssetsCurrent', 'unit': 'u_usd', 'label': 'Other current assets', 'value': 25723000000}, {'concept': 'us-gaap_AssetsCurrent', 'unit': 'u_usd', 'label': 'Assets, Current', 'value': 191131000000}, {'concept': 'us-gaap_PropertyPlantAndEquipmentNet', 'unit': 'u_usd', 'label': 'Property, Plant and Equipment, Net', 'value': 204966000000.0}, {'concept': 'us-gaap_OperatingLeaseRightOfUseAsset', 'unit': 'u_usd', 'label': 'Operating Lease, Right-of-Use Asset', 'value': 24823000000.0}, {'concept': 'us-gaap_LongTermInvestments', 'unit': 'u_usd', 'label': 'Long-Term Investments', 'value': 15405000000.0}, {'concept': 'us-gaap_Goodwill', 'unit': 'u_usd', 'label': 'Goodwill', 'value': 119509000000.0}, {'concept': 'us-gaap_FiniteLivedIntangibleAssetsNet', 'unit': 'u_usd', 'label': 'Finite-Lived Intangible Assets, Net', 'value': 22604000000.0}, {'concept': 'us-gaap_OtherAssetsNoncurrent', 'unit': 'u_usd', 'label': 'Other long-term assets', 'value': 40565000000}, {'concept': 'us-gaap_Assets', 'unit': 'u_usd', 'label': 'Assets', 'value': 619003000000}, {'concept': 'us-gaap_AccountsPayableCurrent', 'unit': 'u_usd', 'label': 'Accounts Payable, Current', 'value': 27724000000}, {'concept': 'us-gaap_CommercialPaper', 'unit': 'u_usd', 'label': 'Commercial Paper', 'value': 0.0}, {'concept': 'us-gaap_LongTermDebtCurrent', 'unit': 'u_usd', 'label': 'Long-Term Debt, Current Maturities', 'value': 2999000000.0}, {'concept': 'us-gaap_EmployeeRelatedLiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Employee-related Liabilities, Current', 'value': 13709000000}, {'concept': 'us-gaap_AccruedIncomeTaxesCurrent', 'unit': 'u_usd', 'label': 'Accrued Income Taxes, Current', 'value': 7211000000}, {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent', 'unit': 'u_usd', 'label': 'Contract with Customer, Liability, Current', 'value': 64555000000}, {'concept': 'us-gaap_OtherLiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Other current liabilities', 'value': 25020000000}, {'concept': 'us-gaap_LiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Liabilities, Current', 'value': 141218000000}, {'concept': 'us-gaap_LongTermDebtNoncurrent', 'unit': 'u_usd', 'label': 'Long-Term Debt, Excluding Current Maturities', 'value': 40152000000.0}, {'concept': 'us-gaap_AccruedIncomeTaxesNoncurrent', 'unit': 'u_usd', 'label': 'Accrued Income Taxes, Noncurrent', 'value': 25986000000}, {'concept': 'us-gaap_ContractWithCustomerLiabilityNoncurrent', 'unit': 'u_usd', 'label': 'Contract with Customer, Liability, Noncurrent', 'value': 2710000000}, {'concept': 'us-gaap_DeferredIncomeTaxLiabilitiesNet', 'unit': 'u_usd', 'label': 'Deferred Income Tax Liabilities, Net', 'value': 2835000000.0}, {'concept': 'us-gaap_OperatingLeaseLiabilityNoncurrent', 'unit': 'u_usd', 'label': 'Operating Lease, Liability, Noncurrent', 'value': 17437000000}, {'concept': 'us-gaap_OtherLiabilitiesNoncurrent', 'unit': 'u_usd', 'label': 'Other long-term liabilities', 'value': 45186000000}, {'con ...
# [{'accessNumber': '0000950170-25-100235', 'symbol': 'MSFT', 'cik': '789019', 'year': 2025, 'quarter': 0, 'form': '10-K', 'startDate': '2024-07-01 00:00:00', 'endDate': '2025-06-30 00:00:00', 'filedDate': '2025-07-30 00:00:00', 'acceptedDate': '2025-07-30 16:11:40', 'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue', 'unit': 'u_usd', 'label': 'Cash and Cash Equivalents, at Carrying Value', 'value': 30242000000.0}, {'concept': 'us-gaap_ShortTermInvestments', 'unit': 'u_usd', 'label': 'Short-Term Investments', 'value': 64323000000.0}, {'concept': 'us-gaap_CashCashEquivalentsAndShortTermInvestments', 'unit': 'u_usd', 'label': 'Cash, Cash Equivalents, and Short-Term Investments', 'value': 94565000000}, {'concept': 'us-gaap_AccountsReceivableNetCurrent', 'unit': 'u_usd', 'label': 'Accounts Receivable, after Allowance for Credit Loss, Current', 'value': 69905000000}, {'concept': 'us-gaap_InventoryNet', 'unit': 'u_usd', 'label': 'Inventory, Net', 'value': 938000000}, {'concept': 'us-gaap_OtherAssetsCurrent', 'unit': 'u_usd', 'label': 'Other current assets', 'value': 25723000000}, {'concept': 'us-gaap_AssetsCurrent', 'unit': 'u_usd', 'label': 'Assets, Current', 'value': 191131000000}, {'concept': 'us-gaap_PropertyPlantAndEquipmentNet', 'unit': 'u_usd', 'label': 'Property, Plant and Equipment, Net', 'value': 204966000000.0}, {'concept': 'us-gaap_OperatingLeaseRightOfUseAsset', 'unit': 'u_usd', 'label': 'Operating Lease, Right-of-Use Asset', 'value': 24823000000.0}, {'concept': 'us-gaap_LongTermInvestments', 'unit': 'u_usd', 'label': 'Long-Term Investments', 'value': 15405000000.0}, {'concept': 'us-gaap_Goodwill', 'unit': 'u_usd', 'label': 'Goodwill', 'value': 119509000000.0}, {'concept': 'us-gaap_FiniteLivedIntangibleAssetsNet', 'unit': 'u_usd', 'label': 'Finite-Lived Intangible Assets, Net', 'value': 22604000000.0}, {'concept': 'us-gaap_OtherAssetsNoncurrent', 'unit': 'u_usd', 'label': 'Other long-term assets', 'value': 40565000000}, {'concept': 'us-gaap_Assets', 'unit': 'u_usd', 'label': 'Assets', 'value': 619003000000}, {'concept': 'us-gaap_AccountsPayableCurrent', 'unit': 'u_usd', 'label': 'Accounts Payable, Current', 'value': 27724000000}, {'concept': 'us-gaap_CommercialPaper', 'unit': 'u_usd', 'label': 'Commercial Paper', 'value': 0.0}, {'concept': 'us-gaap_LongTermDebtCurrent', 'unit': 'u_usd', 'label': 'Long-Term Debt, Current Maturities', 'value': 2999000000.0}, {'concept': 'us-gaap_EmployeeRelatedLiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Employee-related Liabilities, Current', 'value': 13709000000}, {'concept': 'us-gaap_AccruedIncomeTaxesCurrent', 'unit': 'u_usd', 'label': 'Accrued Income Taxes, Current', 'value': 7211000000}, {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent', 'unit': 'u_usd', 'label': 'Contract with Customer, Liability, Current', 'value': 64555000000}, {'concept': 'us-gaap_OtherLiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Other current liabilities', 'value': 25020000000}, {'concept': 'us-gaap_LiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Liabilities, Current', 'value': 141218000000}, {'concept': 'us-gaap_LongTermDebtNoncurrent', 'unit': 'u_usd', 'label': 'Long-Term Debt, Excluding Current Maturities', 'value': 40152000000.0}, {'concept': 'us-gaap_AccruedIncomeTaxesNoncurrent', 'unit': 'u_usd', 'label': 'Accrued Income Taxes, Noncurrent', 'value': 25986000000}, {'concept': 'us-gaap_ContractWithCustomerLiabilityNoncurrent', 'unit': 'u_usd', 'label': 'Contract with Customer, Liability, Noncurrent', 'value': 2710000000}, {'concept': 'us-gaap_DeferredIncomeTaxLiabilitiesNet', 'unit': 'u_usd', 'label': 'Deferred Income Tax Liabilities, Net', 'value': 2835000000.0}, {'concept': 'us-gaap_OperatingLeaseLiabilityNoncurrent', 'unit': 'u_usd', 'label': 'Operating Lease, Liability, Noncurrent', 'value': 17437000000}, {'concept': 'us-gaap_OtherLiabilitiesNoncurrent', 'unit': 'u_usd', 'label': 'Other long-term liabilities', 'value': 45186000000}, {'concept': 'us-gaap_Liabilitie ...
# 2025
# [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue', 'unit': 'u_usd', 'label': 'Cash and Cash Equivalents, at Carrying Value', 'value': 30242000000.0}, {'concept': 'us-gaap_ShortTermInvestments', 'unit': 'u_usd', 'label': 'Short-Term Investments', 'value': 64323000000.0}, {'concept': 'us-gaap_CashCashEquivalentsAndShortTermInvestments', 'unit': 'u_usd', 'label': 'Cash, Cash Equivalents, and Short-Term Investments', 'value': 94565000000}, {'concept': 'us-gaap_AccountsReceivableNetCurrent', 'unit': 'u_usd', 'label': 'Accounts Receivable, after Allowance for Credit Loss, Current', 'value': 69905000000}, {'concept': 'us-gaap_InventoryNet', 'unit': 'u_usd', 'label': 'Inventory, Net', 'value': 938000000}, {'concept': 'us-gaap_OtherAssetsCurrent', 'unit': 'u_usd', 'label': 'Other current assets', 'value': 25723000000}, {'concept': 'us-gaap_AssetsCurrent', 'unit': 'u_usd', 'label': 'Assets, Current', 'value': 191131000000}, {'concept': 'us-gaap_PropertyPlantAndEquipmentNet', 'unit': 'u_usd', 'label': 'Property, Plant and Equipment, Net', 'value': 204966000000.0}, {'concept': 'us-gaap_OperatingLeaseRightOfUseAsset', 'unit': 'u_usd', 'label': 'Operating Lease, Right-of-Use Asset', 'value': 24823000000.0}, {'concept': 'us-gaap_LongTermInvestments', 'unit': 'u_usd', 'label': 'Long-Term Investments', 'value': 15405000000.0}, {'concept': 'us-gaap_Goodwill', 'unit': 'u_usd', 'label': 'Goodwill', 'value': 119509000000.0}, {'concept': 'us-gaap_FiniteLivedIntangibleAssetsNet', 'unit': 'u_usd', 'label': 'Finite-Lived Intangible Assets, Net', 'value': 22604000000.0}, {'concept': 'us-gaap_OtherAssetsNoncurrent', 'unit': 'u_usd', 'label': 'Other long-term assets', 'value': 40565000000}, {'concept': 'us-gaap_Assets', 'unit': 'u_usd', 'label': 'Assets', 'value': 619003000000}, {'concept': 'us-gaap_AccountsPayableCurrent', 'unit': 'u_usd', 'label': 'Accounts Payable, Current', 'value': 27724000000}, {'concept': 'us-gaap_CommercialPaper', 'unit': 'u_usd', 'label': 'Commercial Paper', 'value': 0.0}, {'concept': 'us-gaap_LongTermDebtCurrent', 'unit': 'u_usd', 'label': 'Long-Term Debt, Current Maturities', 'value': 2999000000.0}, {'concept': 'us-gaap_EmployeeRelatedLiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Employee-related Liabilities, Current', 'value': 13709000000}, {'concept': 'us-gaap_AccruedIncomeTaxesCurrent', 'unit': 'u_usd', 'label': 'Accrued Income Taxes, Current', 'value': 7211000000}, {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent', 'unit': 'u_usd', 'label': 'Contract with Customer, Liability, Current', 'value': 64555000000}, {'concept': 'us-gaap_OtherLiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Other current liabilities', 'value': 25020000000}, {'concept': 'us-gaap_LiabilitiesCurrent', 'unit': 'u_usd', 'label': 'Liabilities, Current', 'value': 141218000000}, {'concept': 'us-gaap_LongTermDebtNoncurrent', 'unit': 'u_usd', 'label': 'Long-Term Debt, Excluding Current Maturities', 'value': 40152000000.0}, {'concept': 'us-gaap_AccruedIncomeTaxesNoncurrent', 'unit': 'u_usd', 'label': 'Accrued Income Taxes, Noncurrent', 'value': 25986000000}, {'concept': 'us-gaap_ContractWithCustomerLiabilityNoncurrent', 'unit': 'u_usd', 'label': 'Contract with Customer, Liability, Noncurrent', 'value': 2710000000}, {'concept': 'us-gaap_DeferredIncomeTaxLiabilitiesNet', 'unit': 'u_usd', 'label': 'Deferred Income Tax Liabilities, Net', 'value': 2835000000.0}, {'concept': 'us-gaap_OperatingLeaseLiabilityNoncurrent', 'unit': 'u_usd', 'label': 'Operating Lease, Liability, Noncurrent', 'value': 17437000000}, {'concept': 'us-gaap_OtherLiabilitiesNoncurrent', 'unit': 'u_usd', 'label': 'Other long-term liabilities', 'value': 45186000000}, {'concept': 'us-gaap_Liabilities', 'unit': 'u_usd', 'label': 'Liabilities', 'value': 275524000000}, {'concept': 'us-gaap_CommonStocksIncludingAdditionalPaidInCapital', 'unit': 'u_usd', 'label': 'Common Stocks, Including Additional Paid in Capital', 'value': 109095000000}, {'concept': 'us-gaap_RetainedEarningsAccu ...
# cash: 2
# None: 0
# cash: 2
# None: 0
# None: 0
# None: 0
# assets: 2
# None: 0
# None: 0
# None: 0
# None: 0
# None: 0
# None: 0
# None: 0
# None: 0
# None: 0
# None: 0
# liabilities: 2
# None: 0
# None: 0
# None: 0
# liabilities: 2
# None: 0
# None: 0
# None: 0
# liabilities: 2
# None: 0
# None: 0
# liabilities: 2
# None: 0
# None: 0
# None: 0
# None: 0
# liabilities: 2
# annual_data : {2025: {'cash': 94565000000, 'assets': 191131000000, 'liabilities': 619003000000}}
# Finanal financial data {'assets': 191131000000, 'liabilities': 619003000000, 'cash': 94565000000, 'debt_ratio': 3.2386321423526274}

# %%
memory.clear()

# %%
def resolve_metric(input):
    print(f'input label: {input}')
    label = input.lower()
    
    print(f'output {label}')

    for key,variations in FINANCIAL_ALIASES:
        print (key,variations)
        for v in variations:
            if v in label:
                print(key) 
                return key
            
    return None

# %%
print(FINANCIAL_METRICS_NEEDED)
# Out:
# {'Cash and cash equivalents', 'Total assets', 'Total liabilities', 'Accounts payable', 'Total current liabilities', 'Inventories'}

# %%
memory.clear()

# %%
def validate_financials(financials):

    print(financials)
    print(type(financials))
    
    if isinstance(financials,dict):
        print('is not dict')
        return False
    
    required_key_fields = ['assets','liabilities','cash','debt_ratio']

    for key in required_key_fields:
        if key not in financials:
            print(f'{key} is not in financials')
            return False
    
    if financials['assets'] <= 0:
        print("asset zero")
        return False
    
    if financials['liabilities'] < 0:
        print('liablity zero')
        return False
    
    if financials['cash'] <= 0:
        print('cash zero')
        return False
    
    if financials['debt_ratio'] < 0:
        print('debt ratio')
        return False
    
    return True
    


def validate_state(required, result):
    errors = []

    print(required)
    print(result)

    for req in required:
        ticker = req['entity']
        needs = req['needs']

        entity_data = result.get(ticker, {})

        print(entity_data)

        for need in needs:
            rule = REQUIRED_STATE.get(need)
            if rule:
                value = entity_data.get(need)

                print(value)

                try:
                    if not rule(value):
                        errors.append(
                            {
                                'ticker': ticker,
                                'field': need,
                                'error': 'invalid'
                            }
                        )
                except:
                    errors.append(
                        {
                            'ticker': ticker,
                            'field': need,
                            'error': 'exception'
                        }
                    )
        
    return errors 

print(validate_state(required,result))
# Out:
# [{'entity': 'AAPL', 'needs': ['price', 'news', 'financials']}, {'entity': 'AMZN', 'needs': ['price', 'news', 'financials']}]
# {'AAPL': {'price': 270.23, 'news': ['Apple Is Getting Ready for One of Its ‘Most Lucrative Product Rollouts Ever.’ Should You Buy AAPL Stock First?', 'Apple Inc. (AAPL): Israel Englander Trims Stake', 'Was Jim Cramer Right About Apple (AAPL)?', 'Apple (AAPL) Rated Sector Weight on Mixed Spending Trends', 'Jim Cramer Reveals Why Apple (AAPL) Stock is Worth it', 'Here’s Why Warren Buffett and Ken Griffin Love Apple (AAPL)'], 'financials': {'assets': 359241000000, 'liabilities': 285508000000, 'cash': 35934000000.0, 'debt_ratio': 0.7947533828265705}}, 'AMZN': {'price': 250.56, 'news': ['As Nvidia Signs a Deal to Sell Amazon 1 Million Chips, Is NVDA or AMZN a Better Magnificent 7 Stock to Buy?', 'Amazon.com, Inc. (AMZN) Advances AI and Satellite Expansion Plans', 'What Makes Amazon.com (AMZN) a Lucrative Investment Opportunity?', 'Amazon (AMZN): Top High-Flying AI Stock to Buy', 'Jim Cramer Reveals What Amazon’s (AMZN) Closely Held Secret Is', 'Jim Cramer Recommended Amazon (AMZN) As A Long Term Stock In January 2025'], 'financials': {'assets': 818042000000.0, 'liabilities': 0, 'cash': 86810000000.0, 'debt_ratio': 0.0}}}
# {'price': 270.23, 'news': ['Apple Is Getting Ready for One of Its ‘Most Lucrative Product Rollouts Ever.’ Should You Buy AAPL Stock First?', 'Apple Inc. (AAPL): Israel Englander Trims Stake', 'Was Jim Cramer Right About Apple (AAPL)?', 'Apple (AAPL) Rated Sector Weight on Mixed Spending Trends', 'Jim Cramer Reveals Why Apple (AAPL) Stock is Worth it', 'Here’s Why Warren Buffett and Ken Griffin Love Apple (AAPL)'], 'financials': {'assets': 359241000000, 'liabilities': 285508000000, 'cash': 35934000000.0, 'debt_ratio': 0.7947533828265705}}
# 270.23
# ['Apple Is Getting Ready for One of Its ‘Most Lucrative Product Rollouts Ever.’ Should You Buy AAPL Stock First?', 'Apple Inc. (AAPL): Israel Englander Trims Stake', 'Was Jim Cramer Right About Apple (AAPL)?', 'Apple (AAPL) Rated Sector Weight on Mixed Spending Trends', 'Jim Cramer Reveals Why Apple (AAPL) Stock is Worth it', 'Here’s Why Warren Buffett and Ken Griffin Love Apple (AAPL)']
# {'assets': 359241000000, 'liabilities': 285508000000, 'cash': 35934000000.0, 'debt_ratio': 0.7947533828265705}
# {'assets': 359241000000, 'liabilities': 285508000000, 'cash': 35934000000.0, 'debt_ratio': 0.7947533828265705}
# <class 'dict'>
# {'price': 250.56, 'news': ['As Nvidia Signs a Deal to Sell Amazon 1 Million Chips, Is NVDA or AMZN a Better Magnificent 7 Stock to Buy?', 'Amazon.com, Inc. (AMZN) Advances AI and Satellite Expansion Plans', 'What Makes Amazon.com (AMZN) a Lucrative Investment Opportunity?', 'Amazon (AMZN): Top High-Flying AI Stock to Buy', 'Jim Cramer Reveals What Amazon’s (AMZN) Closely Held Secret Is', 'Jim Cramer Recommended Amazon (AMZN) As A Long Term Stock In January 2025'], 'financials': {'assets': 818042000000.0, 'liabilities': 0, 'cash': 86810000000.0, 'debt_ratio': 0.0}}
# 250.56
# ['As Nvidia Signs a Deal to Sell Amazon 1 Million Chips, Is NVDA or AMZN a Better Magnificent 7 Stock to Buy?', 'Amazon.com, Inc. (AMZN) Advances AI and Satellite Expansion Plans', 'What Makes Amazon.com (AMZN) a Lucrative Investment Opportunity?', 'Amazon (AMZN): Top High-Flying AI Stock to Buy', 'Jim Cramer Reveals What Amazon’s (AMZN) Closely Held Secret Is', 'Jim Cramer Recommended Amazon (AMZN) As A Long Term Stock In January 2025']
# {'assets': 818042000000.0, 'liabilities': 0, 'cash': 86810000000.0, 'debt_ratio': 0.0}
# {'assets': 818042000000.0, 'liabilities': 0, 'cash': 86810000000.0, 'debt_ratio': 0.0}
# <class 'dict'>
# []

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(result)
#
# NameError: name 'result' is not defined

# %%
def compute_metrics(financials,year):
    print(financials)
    
    assets = financials[year].get('Total assets', 0)
    liabilities = financials[year].get('Total liabilities', 0)
    cash = financials[year].get('Cash and cash equivalents', 0)

    try:
        debt_ratio = liabilities/assets
    except:
        debt_ratio = 0
    
    return {
        "assets": assets,
        "liabilities": liabilities,
        "cash": cash,
        "debt_ratio": debt_ratio
    }

print(compute_metrics(annual_data,curr_year))
# Out:
# {2025: {'Cash and cash equivalents': 35934000000.0, 'Marketable securities': 77723000000.0, 'Accounts receivable, net': 39777000000, 'Vendor non-trade receivables': 33180000000, 'Inventories': 5718000000, 'Other current assets': 14585000000, 'Total current assets': 147957000000, 'Property, plant and equipment, net': 49834000000.0, 'Other non-current assets': 83727000000.0, 'Total non-current assets': 211284000000, 'Total assets': 359241000000, 'Accounts payable': 69860000000, 'Other current liabilities': 66387000000.0, 'Deferred revenue': 9055000000, 'Commercial paper': 7979000000, 'Term debt': 78328000000.0, 'Total current liabilities': 165631000000, 'Other non-current liabilities': 41549000000, 'Total non-current liabilities': 119877000000, 'Total liabilities': 285508000000, 'Common stock, shares issued (in shares)': 14773260000, 'Common stock, shares outstanding (in shares)': 14773260000, 'Common stock and additional paid-in capital, $0.00001 par value: 50,400,000 shares authorized; 14,773,260 and 15,116,786 shares issued and outstanding, respectively': 93568000000, 'Accumulated deficit': -14264000000, 'Accumulated other comprehensive loss': -5571000000, 'Total shareholders’ equity': 73733000000.0, 'Total liabilities and shareholders’ equity': 359241000000}}
# {'assets': 359241000000, 'liabilities': 285508000000, 'cash': 35934000000.0, 'debt_ratio': 0.7947533828265705}

# %%
def llmcall(prompt):
    client = genai.Client(api_key='AIzaSyBXxSjUUjhw9n8F1NFQXIfFf51sv6RA_EU')
    response = client.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents={"text": prompt}
    )

    return (response.text)

def generate_output(result,intent):
    generated_output = []
    temp_word = ''
    for ticker,info in result.items():

        if 'price' in intent['basis'] and 'news' in intent['basis'] and 'financials' in intent['basis']:
            temp_word = f"{ticker} - price is {info['price']} and news is {info['news']} and financial data is {info['financials']}" 
        elif 'price' in intent['basis']:
            temp_word = f"price of {ticker} is {info['price']}"
        elif 'news' in intent['basis']:
            temp_word = f"news of ticker {ticker} is \n" +  "\n".join(info['news'])  
        elif 'analysis' in intent['basis']:
            temp_word = f"analyse stock {ticker} with its price {info['price']}, news {info['news']} and financial data is {info['financials']}"
        
        generated_output.append(temp_word)

    print(generated_output)
    if intent['compare'] and set(intent['basis']) == {'price','news','financials'}:
        prompt = f''' 
        You're a financial assistant.

        ONLY use the raw data below.
        DO NOT assume or add extra knowledge.

        Data:
        {generated_output}
        
        Task:
        compare and give best stock.

        Rules:
        Max 5 lines
        No Assumptions
        If data is insufficient, say "insufficient data" 
        '''
        final_output = llmcall(prompt)
    
    
    elif 'analysis' in intent['basis']:
        prompt = f''' 
        You're a financial assistant

        ONLY use raw data below. 
        DO NOT assume or add extra knowledge 

        Data: 
        {generated_output}
        
        Task:
        Analyze and give niche results 

        Rules:
        Max 5 lines
        No Assumptions
        If data is insufficient, say "insufficient data" 
        '''
        final_output = llmcall(prompt)
    
    else:
        final_output = '\n'.join(generated_output)

    return final_output
    
print(generate_output(result,intent))
# Out:
# ["AAPL - price is 262.46 and news is ['Apple Is Getting Ready for One of Its ‘Most Lucrative Product Rollouts Ever.’ Should You Buy AAPL Stock First?', 'Apple Inc. (AAPL): Israel Englander Trims Stake', 'Was Jim Cramer Right About Apple (AAPL)?', 'Apple (AAPL) Rated Sector Weight on Mixed Spending Trends', 'Apple (AAPL) Rose on Better-Than-Feared iPhone 17 Sales', 'Apple Inc. (AAPL): D. E. Shaw Trims Holding'] and financial data is {2025: {'Cash and cash equivalents': 35934000000.0, 'Inventories': 5718000000, 'Total assets': 359241000000, 'Accounts payable': 69860000000, 'Total liabilities': 285508000000}, 2024: {'Cash and cash equivalents': 29943000000.0, 'Inventories': 7286000000, 'Total assets': 364980000000, 'Accounts payable': 68960000000, 'Total liabilities': 308030000000}, 2023: {'Cash and cash equivalents': 29965000000.0, 'Inventories': 6331000000, 'Total assets': 352583000000, 'Accounts payable': 62611000000, 'Total liabilities': 290437000000}, 2022: {'Cash and cash equivalents': 23646000000.0, 'Inventories': 4946000000, 'Total assets': 352755000000, 'Accounts payable': 64115000000, 'Total liabilities': 302083000000}, 2021: {'Cash and cash equivalents': 34940000000.0, 'Inventories': 6580000000, 'Total assets': 351002000000, 'Accounts payable': 54763000000, 'Total liabilities': 287912000000}, 2020: {'Cash and cash equivalents': 38016000000.0, 'Inventories': 4061000000, 'Total assets': 323888000000, 'Accounts payable': 42296000000, 'Total liabilities': 258549000000}, 2019: {'Inventories': 4106000000, 'Total assets': 338516000000, 'Accounts payable': 46236000000, 'Total liabilities': 248028000000}, 2018: {'Accounts payable': 55888000000, 'Total assets': 365725000000, 'Inventories': 3956000000, 'Total liabilities': 258578000000}, 2017: {'Accounts payable': 49049000000, 'Total assets': 375319000000, 'Inventories': 4855000000, 'Total liabilities': 241272000000}, 2016: {'Accounts payable': 37294000000, 'Total assets': 321686000000, 'Cash and cash equivalents': 20484000000, 'Inventories': 2132000000, 'Total liabilities': 193437000000}, 2015: {}, 2014: {}, 2013: {}, 2012: {}, 2011: {'Total assets': 116371000000, 'Inventories': 776000000, 'Total liabilities': 39756000000}, 2010: {'Cash and cash equivalents': 11261000000, 'Inventories': 1051000000, 'Total liabilities': 27392000000}}", "AMZN - price is 247.79 and news is ['As Nvidia Signs a Deal to Sell Amazon 1 Million Chips, Is NVDA or AMZN a Better Magnificent 7 Stock to Buy?', 'Amazon.com, Inc. (AMZN) Advances AI and Satellite Expansion Plans', 'What Makes Amazon.com (AMZN) a Lucrative Investment Opportunity?', 'Amazon (AMZN): Top High-Flying AI Stock to Buy', 'Jim Cramer Recommended Amazon (AMZN) As A Long Term Stock In January 2025', 'Here’s Why Jim Cramer Likes Amazon (AMZN) in 2026 Despite Unimpressive Performance'] and financial data is {2025: {'Cash and cash equivalents': 86810000000.0, 'Inventories': 38325000000, 'Total assets': 818042000000.0, 'Accounts payable': 121909000000}, 2024: {'Cash and cash equivalents': 78779000000.0, 'Inventories': 34214000000, 'Total assets': 624894000000.0, 'Accounts payable': 94363000000}, 2023: {'Cash and cash equivalents': 73387000000.0, 'Inventories': 33318000000, 'Total assets': 527854000000.0, 'Accounts payable': 84981000000}, 2022: {'Cash and cash equivalents': 53888000000.0, 'Inventories': 34405000000, 'Total assets': 462675000000.0, 'Accounts payable': 79600000000}, 2021: {'Cash and cash equivalents': 36220000000.0, 'Inventories': 32640000000.0, 'Total assets': 420549000000.0, 'Accounts payable': 78664000000.0}, 2020: {'Cash and cash equivalents': 42122000000.0, 'Inventories': 23795000000.0, 'Total assets': 321195000000.0, 'Accounts payable': 72539000000.0}, 2019: {'Cash and cash equivalents': 36092000000.0, 'Inventories': 20497000000, 'Total assets': 225248000000.0, 'Accounts payable': 47183000000}, 2018: {'Accounts payable': 38192000000, 'Total assets': 162648000000, 'Cash and cash equivalents': 31750000000, 'Inventories': 1717 ...
# insufficient data

# %%
print(result)
# Out:
# none

# %%
import requests
api_url = "https://finnhub.io/api/v1/stock/financials-reported"

params = { 
    "symbol": 'AMZN',
    "token": 'd6v6jk9r01qig546muf0d6v6jk9r01qig546mufg'
}


print(requests.get(api_url,params=params).json())
# Out:
# {'cik': '1018724', 'data': [{'accessNumber': '0001018724-26-000004', 'symbol': 'AMZN', 'cik': '1018724', 'year': 2025, 'quarter': 0, 'form': '10-K', 'startDate': '2025-01-01 00:00:00', 'endDate': '2025-12-31 00:00:00', 'filedDate': '2026-02-06 00:00:00', 'acceptedDate': '2026-02-05 18:44:31', 'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue', 'unit': 'usd', 'label': 'Cash and cash equivalents', 'value': 86810000000.0}, {'concept': 'us-gaap_MarketableSecuritiesCurrent', 'unit': 'usd', 'label': 'Marketable securities', 'value': 36219000000}, {'concept': 'us-gaap_InventoryNet', 'unit': 'usd', 'label': 'Inventories', 'value': 38325000000}, {'concept': 'us-gaap_AccountsReceivableNetCurrent', 'unit': 'usd', 'label': 'Accounts receivable, net and other', 'value': 67729000000}, {'concept': 'us-gaap_AssetsCurrent', 'unit': 'usd', 'label': 'Total current assets', 'value': 229083000000}, {'concept': 'us-gaap_PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAfterAccumulatedDepreciationAndAmortization', 'unit': 'usd', 'label': 'Property and equipment, net', 'value': 357025000000.0}, {'concept': 'us-gaap_OperatingLeaseRightOfUseAsset', 'unit': 'usd', 'label': 'Operating leases', 'value': 86054000000}, {'concept': 'us-gaap_Goodwill', 'unit': 'usd', 'label': 'Goodwill', 'value': 23273000000.0}, {'concept': 'us-gaap_OtherAssetsNoncurrent', 'unit': 'usd', 'label': 'Other assets', 'value': 122607000000}, {'concept': 'us-gaap_Assets', 'unit': 'usd', 'label': 'Total assets', 'value': 818042000000.0}, {'concept': 'us-gaap_AccountsPayableCurrent', 'unit': 'usd', 'label': 'Accounts payable', 'value': 121909000000}, {'concept': 'us-gaap_AccruedLiabilitiesCurrent', 'unit': 'usd', 'label': 'Accrued expenses and other', 'value': 75520000000}, {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent', 'unit': 'usd', 'label': 'Unearned revenue', 'value': 20576000000}, {'concept': 'us-gaap_LiabilitiesCurrent', 'unit': 'usd', 'label': 'Total current liabilities', 'value': 218005000000}, {'concept': 'amzn_LeaseLiabilityNoncurrent', 'unit': 'usd', 'label': 'Long-term lease liabilities', 'value': 87339000000.0}, {'concept': 'us-gaap_LongTermDebtNoncurrent', 'unit': 'usd', 'label': 'Long-term debt', 'value': 65648000000}, {'concept': 'us-gaap_OtherLiabilitiesNoncurrent', 'unit': 'usd', 'label': 'Other long-term liabilities', 'value': 35985000000}, {'concept': 'us-gaap_PreferredStockValue', 'unit': 'usd', 'label': 'Preferred stock ($0.01 par value; 500 shares authorized; no shares issued or outstanding)', 'value': 0}, {'concept': 'us-gaap_CommonStockValue', 'unit': 'usd', 'label': 'Common stock ($0.01 par value; 100,000 shares authorized; 11,108 and 11,246 shares issued; 10,593 and 10,731 shares outstanding)', 'value': 112000000}, {'concept': 'us-gaap_TreasuryStockCommonValue', 'unit': 'usd', 'label': 'Treasury stock, at cost', 'value': 7837000000}, {'concept': 'us-gaap_AdditionalPaidInCapital', 'unit': 'usd', 'label': 'Additional paid-in capital', 'value': 140024000000}, {'concept': 'us-gaap_AccumulatedOtherComprehensiveIncomeLossNetOfTax', 'unit': 'usd', 'label': 'Accumulated other comprehensive income (loss)', 'value': 28230000000}, {'concept': 'us-gaap_RetainedEarningsAccumulatedDeficit', 'unit': 'usd', 'label': 'Retained earnings', 'value': 250536000000}, {'concept': 'us-gaap_StockholdersEquity', 'unit': 'usd', 'label': 'Total stockholders’ equity', 'value': 411065000000.0}, {'concept': 'us-gaap_LiabilitiesAndStockholdersEquity', 'unit': 'usd', 'label': 'Total liabilities and stockholders’ equity', 'value': 818042000000}], 'ic': [{'concept': 'us-gaap_IncomeLossFromEquityMethodInvestments', 'unit': 'usd', 'label': 'Equity-method investment activity, net of tax', 'value': -554000000.0}, {'concept': 'us-gaap_NetIncomeLoss', 'unit': 'usd', 'label': 'Net income', 'value': 77670000000.0}, {'concept': 'us-gaap_RevenueFromContractWithCustomerExcludingAssessedTax', 'unit': 'usd', 'label': 'Total net sales', 'value': 716924000000.0}, ...

# %%
response = requests.get(api_url,params=params).json()
data = response['data']

annual_data = {}

FINANCIAL_METRICS_NEEDED = {'Total assets', 'Total liabilities', 'Cash and cash equivalents', 'Accounts payable', 'Inventories'}
print(data[0])

curr_data = data[0]
curr_year = data[0]['year']
# print(curr_year)
reports = curr_data['report']['bs']
# print(reports)

annual_data[curr_year] = {}

for details in reports:
    # if details['label'] in FINANCIAL_METRICS_NEEDED:
            try:
                annual_data[curr_year][details['label']] = details['value']
            except Exception:
                annual_data[curr_year][details['label']] = 0

# for item in data[0]: 
#     print(item)
#     curr_year = max(item['year'])
#     annual_data[curr_year] = {}
#     reports = item['report']['bs']
#     for details in reports:
#         if details['label'] in FINANCIAL_METRICS_NEEDED:
#             try:
#                 annual_data[curr_year][details['label']] = details['value']
#             except Exception:
#                 annual_data[curr_year][details['label']] = 0

    
#     # yearly_data.append(annual_data)
        

# bs = data[0]['report']['bs']


# for items in bs:
#     yearly_data[items['label']] = items['value']


print(annual_data)
# Out:
# {'accessNumber': '0001018724-26-000004', 'symbol': 'AMZN', 'cik': '1018724', 'year': 2025, 'quarter': 0, 'form': '10-K', 'startDate': '2025-01-01 00:00:00', 'endDate': '2025-12-31 00:00:00', 'filedDate': '2026-02-06 00:00:00', 'acceptedDate': '2026-02-05 18:44:31', 'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue', 'unit': 'usd', 'label': 'Cash and cash equivalents', 'value': 86810000000.0}, {'concept': 'us-gaap_MarketableSecuritiesCurrent', 'unit': 'usd', 'label': 'Marketable securities', 'value': 36219000000}, {'concept': 'us-gaap_InventoryNet', 'unit': 'usd', 'label': 'Inventories', 'value': 38325000000}, {'concept': 'us-gaap_AccountsReceivableNetCurrent', 'unit': 'usd', 'label': 'Accounts receivable, net and other', 'value': 67729000000}, {'concept': 'us-gaap_AssetsCurrent', 'unit': 'usd', 'label': 'Total current assets', 'value': 229083000000}, {'concept': 'us-gaap_PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAfterAccumulatedDepreciationAndAmortization', 'unit': 'usd', 'label': 'Property and equipment, net', 'value': 357025000000.0}, {'concept': 'us-gaap_OperatingLeaseRightOfUseAsset', 'unit': 'usd', 'label': 'Operating leases', 'value': 86054000000}, {'concept': 'us-gaap_Goodwill', 'unit': 'usd', 'label': 'Goodwill', 'value': 23273000000.0}, {'concept': 'us-gaap_OtherAssetsNoncurrent', 'unit': 'usd', 'label': 'Other assets', 'value': 122607000000}, {'concept': 'us-gaap_Assets', 'unit': 'usd', 'label': 'Total assets', 'value': 818042000000.0}, {'concept': 'us-gaap_AccountsPayableCurrent', 'unit': 'usd', 'label': 'Accounts payable', 'value': 121909000000}, {'concept': 'us-gaap_AccruedLiabilitiesCurrent', 'unit': 'usd', 'label': 'Accrued expenses and other', 'value': 75520000000}, {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent', 'unit': 'usd', 'label': 'Unearned revenue', 'value': 20576000000}, {'concept': 'us-gaap_LiabilitiesCurrent', 'unit': 'usd', 'label': 'Total current liabilities', 'value': 218005000000}, {'concept': 'amzn_LeaseLiabilityNoncurrent', 'unit': 'usd', 'label': 'Long-term lease liabilities', 'value': 87339000000.0}, {'concept': 'us-gaap_LongTermDebtNoncurrent', 'unit': 'usd', 'label': 'Long-term debt', 'value': 65648000000}, {'concept': 'us-gaap_OtherLiabilitiesNoncurrent', 'unit': 'usd', 'label': 'Other long-term liabilities', 'value': 35985000000}, {'concept': 'us-gaap_PreferredStockValue', 'unit': 'usd', 'label': 'Preferred stock ($0.01 par value; 500 shares authorized; no shares issued or outstanding)', 'value': 0}, {'concept': 'us-gaap_CommonStockValue', 'unit': 'usd', 'label': 'Common stock ($0.01 par value; 100,000 shares authorized; 11,108 and 11,246 shares issued; 10,593 and 10,731 shares outstanding)', 'value': 112000000}, {'concept': 'us-gaap_TreasuryStockCommonValue', 'unit': 'usd', 'label': 'Treasury stock, at cost', 'value': 7837000000}, {'concept': 'us-gaap_AdditionalPaidInCapital', 'unit': 'usd', 'label': 'Additional paid-in capital', 'value': 140024000000}, {'concept': 'us-gaap_AccumulatedOtherComprehensiveIncomeLossNetOfTax', 'unit': 'usd', 'label': 'Accumulated other comprehensive income (loss)', 'value': 28230000000}, {'concept': 'us-gaap_RetainedEarningsAccumulatedDeficit', 'unit': 'usd', 'label': 'Retained earnings', 'value': 250536000000}, {'concept': 'us-gaap_StockholdersEquity', 'unit': 'usd', 'label': 'Total stockholders’ equity', 'value': 411065000000.0}, {'concept': 'us-gaap_LiabilitiesAndStockholdersEquity', 'unit': 'usd', 'label': 'Total liabilities and stockholders’ equity', 'value': 818042000000}], 'ic': [{'concept': 'us-gaap_IncomeLossFromEquityMethodInvestments', 'unit': 'usd', 'label': 'Equity-method investment activity, net of tax', 'value': -554000000.0}, {'concept': 'us-gaap_NetIncomeLoss', 'unit': 'usd', 'label': 'Net income', 'value': 77670000000.0}, {'concept': 'us-gaap_RevenueFromContractWithCustomerExcludingAssessedTax', 'unit': 'usd', 'label': 'Total net sales', 'value': 716924000000.0}, {'concept': 'us-gaap_CostOf ...
# {2025: {'Cash and cash equivalents': 86810000000.0, 'Marketable securities': 36219000000, 'Inventories': 38325000000, 'Accounts receivable, net and other': 67729000000, 'Total current assets': 229083000000, 'Property and equipment, net': 357025000000.0, 'Operating leases': 86054000000, 'Goodwill': 23273000000.0, 'Other assets': 122607000000, 'Total assets': 818042000000.0, 'Accounts payable': 121909000000, 'Accrued expenses and other': 75520000000, 'Unearned revenue': 20576000000, 'Total current liabilities': 218005000000, 'Long-term lease liabilities': 87339000000.0, 'Long-term debt': 65648000000, 'Other long-term liabilities': 35985000000, 'Preferred stock ($0.01 par value; 500 shares authorized; no shares issued or outstanding)': 0, 'Common stock ($0.01 par value; 100,000 shares authorized; 11,108 and 11,246 shares issued; 10,593 and 10,731 shares outstanding)': 112000000, 'Treasury stock, at cost': 7837000000, 'Additional paid-in capital': 140024000000, 'Accumulated other comprehensive income (loss)': 28230000000, 'Retained earnings': 250536000000, 'Total stockholders’ equity': 411065000000.0, 'Total liabilities and stockholders’ equity': 818042000000}}

# %%
for item in data:
    print(item['year'])
# Out:
# 2025
# 2024
# 2023
# 2022
# 2021
# 2020
# 2019
# 2018
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010

# %%
print(generate_output(result,intent))
# Out:
# insufficient data

# %%
print(intent)
print(required)
print(result)
# Out:
# {'compare': True, 'basis': ['analysis']}
# [{'entity': 'TSLA', 'needs': ['analysis']}]
# {'TSLA': {}}

# %%
try:
    resp = re.sub(r"```json|```", "", llmcall(prompt))
    print(resp)
    response = json.loads(resp)
except Exception as ex1:
    print(f'LLM response JSON load failed  - Exception is {ex1}')

try:
    if len(response['tickers']) == 0: 
        print(f'Please enter a stock related query')
        sys.exit()
except Exception as ex2:
    print(f'Exception occured during validation of entity extraction - {ex2}')
    sys.exit()



company_names = response['tickers']
new_entries = []

for ticker in company_names:
    exists = False 
    for items in entities:
        if ticker == items['ticker']:
            exists = True
    
    if not exists:
        new_entity = {
            'ticker': ticker,
            'price': None,
            'news': None
        }
        new_entries.append(new_entity)


entities.extend(new_entries)


print(entities)
# Out:
# {"tickers": ["AAPL", "AMZN"]}
# [{'ticker': 'AAPL', 'price': None, 'news': None}, {'ticker': 'AMZN', 'price': None, 'news': None}]

# %%
print(response)

# %%
print(response.split(','))
print(response)

# %%
company = response.split(',')
print(company)

# %%
print(generate_output(result,intent))

# %%
set(intent['basis'])

# %%
print(generate_output(result,intent))

# %%
    client = anthropic.Anthropic(api_key='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')

    message = client.messages.create(
        model="claude-sonnet-4-6",
        max_tokens=100,
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
    )

# %%
def check_required(query):
    intent = get_intent(query)
    entity = entity_extraction(query)

    required = []
    print(intent)
    
    if len(entity) == 0:
        return "none","none"

    if intent['basis']: 
        req = intent['basis']
    elif intent['compare']:
        req = ['price','news']
        intent['basis'] = req
    else:
        return "none","none"
        
    for enty in entity:
        new_req = {
            'entity': enty['ticker'],
            'needs': req
            }
        required.append(new_req)

    return required,intent

required,intent = check_required(query)
print(required)
print(intent)

# %%
print(intent)
print(result)
print(required)

# %%
def recover_state(result, errors):
    for error in errors:
        for ticker,val in error.items(): 
            print(ticker)
            print(val)
            print(ERROR_FUNCTION.get(val))
            err_fun = ERROR_FUNCTION.get(val)
            err_val = ERROR_MAP.get(val)
            print(err_fun)
            print(err_val)
            if err_fun:
                if err_val:
                    prev_val = result[ticker][err_val]
                    result[ticker][err_val] = err_fun(ticker)
                    curr_val = result[ticker][err_val]
                    if prev_val == curr_val:
                        return "none" 
    
    return result

final_result = recover_state(result,err)

print(final_result)

# %%
def validate_state(required, result):
    errors = []
    

    for req in required:
        err = {}
        print(f'req: {req}')
        print(f'bef err: {err}')
        ticker = req['entity']
        needs = req['needs']

        entity_data = result.get(ticker, {})

        for need in needs:
            print(f'need: {need}')
            rule = REQUIRED_STATE.get(need)
            if rule:
                value = entity_data.get(need)

                if not rule(value):
                    print(f'err: {err}')
                    print(f'errors {errors}')
                    print(f'ticker {ticker}')
                    if ticker in err:
                        print(err[ticker])
                        err[ticker].append(f'invalid {need}') 
                    else: 
                        err[ticker] = f'invalid {need}'
                    print(f'after err: {err}')
                    errors.append(err)
        
    return errors 

err = validate_state(required,result)
print(err)

# %%
print(result)

# %%
def generate_output(result,mode):
    generated_output = []
    if mode == 'compare':
        for items in result:
            for ticker,info in items.items():
                print(ticker)
                print(info['price'])
                if info['price'] and info['news']:
                    temp_word = f"{ticker} - price is {info['price']} and news is {info['news']}" 
                elif info['price']:
                    temp_word = f"price of {ticker} is {info['price']}"
                elif result[ticker]['news']:
                    temp_word = f"news of ticker {ticker} is \n" +  "\n".join(info['news'])          

                generated_output.append(temp_word)

    elif mode == 'analysis':
        for ticker in result:
            for ticker,info in items.items():
                if info['price'] and info['news']:
                    temp_word = f"{ticker} - price is {info['price']} and news is {info['news']}" 
                generated_output.append(temp_word)
        

    elif mode == 'price':
        for items in result:
            for ticker,info in items.items():
                temp_word = f"price of {ticker} is {info['price']}"
                generated_output.append(temp_word)
        
    elif mode == 'news':
        for items in result:
            for ticker,info in items.items():
                temp_word = f"news of ticker {ticker} is \n" +  "\n".join(info['news'])    
                generated_output.append(temp_word)
    
    return generated_output

print(generate_output(result,mode))

# %%
def validate_output(result,mode):
    errors = []
    print (result)
    for ticker,info in result.items():
        price_counter = 0
        news_counter = 0
        if "price" in mode:
            try:
                if info['price'] == 0:
                    price_counter += 1
                    if price_counter <=1: 
                        info['price'] = get_price[ticker]
                    else:
                        errors.append[f'invalid price for {ticker}']
            except KeyError: 
                price_counter += 1
                if price_counter <=1: 
                    info['price'] = get_price[ticker]
                else:
                    errors.append[f'invalid price for {ticker}']
            except Exception: 
                errors.append[f'invalid price for {ticker}']

        if "news" in mode:
            try:
                if len(info['news']) == 0:
                    news_counter += 1
                    if news_counter <=1: 
                        info['news'] = get_news[ticker]
                    else:
                        errors.append[f'incorrect news fetch for {ticker}']
            except KeyError:
                news_counter += 1
                if news_counter <= 1:
                    info['news']  = get_news['ticker']
                else:
                    errors.append[f'incorrect news fetch for {ticker}']

    return errors


err = validate_output(result,mode)

if len(err) == 0:
    print(generate_output(result,mode))
else: 
    print("\n".join(err))

# %%
def generate_output(result,mode):
    generated_output = []
    temp_word = ''
    for ticker,info in result.items():
        print (mode)
        if 'price' in mode and 'news' in mode:
            temp_word = f"{ticker} - price is {info['price']} and news is {info['news']}" 
        elif 'price' in mode:
            temp_word = f"price of {ticker} is {info['price']}"
        elif 'news' in mode:
            temp_word = f"news of ticker {ticker} is \n" +  "\n".join(info['news'])    

        generated_output.append(temp_word)
    return generated_output

if len(err) == 0:
    print(generate_output(result,mode))
else: 
    print("\n".join(err))

# %%
def validate_state(required, result):
    errors = []

    for req in required:
        ticker = req['entity']
        needs = req['needs']

        entity_data = result.get(ticker, {})
        print(entity_data)

        for need in needs:
            print(need)
            rule = REQUIRED_STATE.get(need)
            print(rule)
            if rule:
                value = entity_data.get(need)

                if not rule(value):
                    errors.append(f"{ticker}: invalid_{need}")

validate_state(required,result)

# %%
print(err)

# %%
print(intent)
print(required)
print(rule)
