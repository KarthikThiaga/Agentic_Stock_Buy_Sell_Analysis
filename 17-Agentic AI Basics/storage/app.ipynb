# %%
# Out:
# {'google': 'GOOG', 'alphabet': 'GOOG', 'youtube': 'GOOG', 'facebook': 'META', 'meta': 'META', 'amazon': 'AMZN', 'aws': 'AMZN', 'amzn': 'AMZN', 'chase': 'JPM', 'JPMC': 'JPM', 'JP Morgan chase & Co': 'JPM', 'amazn': 'AMZN', 'apple': 'AAPL', 'microsoft': 'MSFT', 'microsft': 'MSFT'}
