# %% [markdown]
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.

# %%
with open("sample.txt","r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello.!
# Karthik Reporting

# %% [markdown]
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.

# %%
str_list = ['apple \n', 'oranges \n', 'fruits']

with open("output,txt","w") as file:
    for items in str_list:
        file.write(items)

# %% [markdown]
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.

# %%
with open("source.txt","r") as file:
    content = file.read()

with open("destination.txt", "w") as file:
    file.write(content)

# %% [markdown]
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `log.txt`.

# %%
with open("log.txt","a") as file:
    file.write("log2 \n")

# %% [markdown]
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.

# %%
total_words = 0
with open('document.txt','r') as file:
    for line in file:
        print((line.strip()).split())
        total_words += len((line.strip()).split())

print(total_words)
# Out:
# ['The', 'sun', 'rises', 'in', 'the', 'east.']
# ['She', 'enjoys', 'reading', 'books', 'in', 'the', 'evening.']
# ['They', 'went', 'to', 'the', 'beach', 'to', 'watch', 'the', 'sunset.']
# 22

# %% [markdown]
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.

# %%
def find_and_replace(filename, old_word, new_word):
    with open(filename, 'r') as file:
        text = file.read()
    new_text = text.replace(old_word, new_word)
    with open(filename, 'w') as file:
        file.write(new_text)

# Test
# find_and_replace('data.txt', 'old', 'new')

# %% [markdown]
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.

# %%
with open('data.txt','r') as file:
    lines=file.readlines()
    for line in reversed(lines):
        print(line)
# Out:
# Suja looks soo cute and awesome
# Cats and gods are as cute as other animals

# %% [markdown]
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.

# %%
def file_counts(filename):
    line_count = 0
    word_count = 0
    char_count = 0
    with open(filename,'r') as file:
        for line in file:
            line_count += 1
            word_count += len(line.split())
            char_count += len(line)
    return [line_count,word_count,char_count]


list_of_counts = file_counts('stats.txt')
print(list_of_counts)
# Out:
# [3, 14, 61]

# %% [markdown]
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %%
def merge_files(list_of_files):
    for files in list_of_files:
        with open(files,'r') as file:
            content = file.read()

        with open('merged.txt','a+') as writefile:
            writefile.read()
            writefile.write(content)


merge_files(['source.txt','stats.txt','log.txt'])

# %% [markdown]
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.

# %%
def file_split(filename,split_frequency):
    line_count = 0
    file_count = 0 
    with open(filename,'r') as file:
        for lines in file:
            line_count += 1
            write_file_name = 'split_' + str(file_count)
            with open(write_file_name,'a+') as writefile:
                writefile.read()
                writefile.write(lines)
            if line_count % 100 == 0: 
                file_count += 1

file_split('large.txt',100)

# %% [markdown]
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.

# %%
import datetime as dt 

def log_file(message,filename='activity.txt'):
    timestamp = dt.datetime.now()
    with open(filename,"a+") as file:
        file.read()
        file.write(f'{message}/{timestamp} \n')


log_file('Manku')

# %% [markdown]
# ### Assignment 12: Binary File Operations
#
# Write a function that reads a binary file named `image.bin` and writes its contents to another binary file named `copy_image.bin`.

# %%
def copy_binary_file(source, destination):
    with open(source, 'rb') as src:
        with open(destination, 'wb') as dest:
            dest.write(src.read())

copy_binary_file('image.bin','copy.bin')

# %% [markdown]
# ### Assignment 13: CSV File Operations
#
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.

# %%
import csv 

def csv_to_dict(source_file):
    with open(source_file,'r') as file:
        reader = csv.DictReader(file)
        return list(reader)
    

dict_new = csv_to_dict('data.csv')
print(dict_new)
# Out:
# [{'Username; Identifier;First name;Last name': 'booker12;9012;Rachel;Booker'}, {'Username; Identifier;First name;Last name': 'grey07;2070;Laura;Grey'}, {'Username; Identifier;First name;Last name': 'johnson81;4081;Craig;Johnson'}, {'Username; Identifier;First name;Last name': 'jenkins46;9346;Mary;Jenkins'}, {'Username; Identifier;First name;Last name': 'smith79;5079;Jamie;Smith'}]

# %% [markdown]
# ### Assignment 14: JSON File Operations
#
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.

# %%
import json

def json_conv(source_file):
    with open(source_file,'r') as file:
        json_dict = json.load(file)
        return(json_dict)
    
dict_of_json = json_conv('data.json')
print(dict_of_json)
# Out:
# {'fruit': 'Apple', 'size': 'Large', 'color': 'Red'}

# %% [markdown]
# ### Assignment 15: File Permission Handling
#
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.

# %%
def check_protect(source_file):
    try:
        with open(source_file,'r') as file:
            file.read()
    except PermissionError:
        print(f'Error opening file {source_file} : Check Authority before opening')
